# %% [markdown]
# # Przygotowanie

# %% [markdown]
# ## Parametryzacja  jupytera

# %%
# change code cells width
from IPython.display import display, HTML
display(
HTML(data = """
<style>
  div#notebook-container {width: 75%;}
  div#menubar-container {width: 65%;}
  div#maintoolbar-container {width: 55%;}
</style>

"""))


# display all outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'



# pandas DataFrame displayed outpu size
import pandas as pd
pd.options.display.max_rows = 100
pd.options.display.max_columns = 20
# Out:
# <style>
#   div#notebook-container {width: 75%;}
#   div#menubar-container {width: 65%;}
#   div#maintoolbar-container {width: 55%;}
# </style>

# %% [markdown]
# ## Pakiety i funkcje

# %%
# pakiety i funkcje

import os
# %run "draft/data_analysis_tools.py"
# %run "draft/F_classification.py"
# %run "draft/grid_search.py"

from IPython.display import display, HTML


def h(text, size = 3, bold = True):
    if not bold:
        return(HTML('<font size = "' + str(size) + '">' + text + '</font>' ))
    else:
        return(HTML('<font size = "' + str(size) + '"><b>' + text + '</b></font>' ))

# %% [markdown]
# ## Zmienne globalne

# %%
# lista dostepnych modeli
models_base = {  'rf' :RandomForestClassifier(n_estimators=10, max_depth=6)
                ,'gb' :GradientBoostingClassifier(n_estimators=10, max_depth = 6)
                ,'cat':CatBoostClassifier(iterations=10,  random_seed=123)
                ,'ab' :AdaBoostClassifier(n_estimators = 30)
                ,'knn':skl.neighbors.KNeighborsClassifier(n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=10, p=2, metric='minkowski')
                ,'nb' :skl.naive_bayes.GaussianNB(priors=None, var_smoothing=1e-09)
#                 ,'lgbm':LGBMClassifier(n_estimators = 50, n_jobs = 5, learning_rate = 0.1, max_depth = 7)
#                 ,'xgb':XGBClassifier(n_estimators = 50, leanring_rate = 0.1, max_depth = 7, n_jobs = 5)
                }

# %% [markdown]
# # Dane

# %% [markdown]
# ## Import i podstawowe charakterystyki

# %%
data = pd.read_csv('data/diamonds.txt', index_col=False)
data = data.drop(data.columns[0], axis = 1)

h('rozmiar danych')
data.shape

h('typy zmiennych')
data.dtypes

h('sktuktura zmiennych')
glimpse_data(data, var_cat = list(data.dtypes[data.dtypes=='object'].index) )
# Out:
# <font size = "3"><b>rozmiar danych</b></font>
# (53940, 12)
# <font size = "3"><b>typy zmiennych</b></font>
# carat                 float64
# cut                    object
# color                  object
# clarity                object
# depth                 float64
# table                 float64
# price                   int64
# x                     float64
# y                     float64
# z                     float64
# target                  int64
# target_multi_label      int64
# dtype: object
# <font size = "3"><b>sktuktura zmiennych</b></font>
#          table      y  target_multi_label  carat      x     price      z  \
# NA         0.0   0.00                 0.0   0.00   0.00      0.00   0.00
# NA_proc    0.0   0.00                 0.0   0.00   0.00      0.00   0.00
# min       43.0   0.00                 0.0   0.20   0.00    326.00   0.00
# q_25      56.0   4.72                 0.0   0.40   4.71    950.00   2.91
# q_50      57.0   5.71                 1.0   0.70   5.70   2401.00   3.53
# q_75      59.0   6.54                 3.0   1.04   6.54   5324.25   4.04
# max       95.0  58.90                 4.0   5.01  10.74  18823.00  31.80
#
#          target  depth                cut      color      clarity
# NA          0.0    0.0                  0          0            0
# NA_proc     0.0    0.0                  0          0            0
# min         0.0   43.0      Ideal (21551)  G (11292)  SI1 (13065)
# q_25        0.0   61.0    Premium (13791)   E (9797)  VS2 (12258)
# q_50        0.0   61.8  Very Good (12082)   F (9542)   SI2 (9194)
# q_75        1.0   62.5        Good (4906)   H (8304)   VS1 (8171)
# max         1.0   79.0        Fair (1610)   D (6775)  VVS2 (5066)

# %% [markdown]
# ## Bardziej zaawansowane statystyki

# %%
var_y = 'target'

gl_result = glimpse_data_extended(  data = data                # dane
                                  , levels_n_limit = 7         # dla zmiennych jakosciowych ile top najczestszych kategorii pokazac
                                  , levels_n_max=35            # DO ilu unilanych kategorii zmienna typu numerycznego jest traktowana jako potencjalna jakosciowa 
                                  , copy_to_clipboard = False) # czy wyniki zapisywac do schowaka (zeby np. szybko skopiowac do excela)

A_F_correlation_selection(data = data, y = var_y, analytical_table_file = gl_result, sheet = None, round = 2)
# Out:
# ratio_not_calculated for cut and target.
# ratio_not_calculated for color and target.
# ratio_not_calculated for clarity and target.
#     index      var  nan_proc rec_type      type  n_levels             0  \
# 0       0    carat       0.0        n   float64       273           NaN
# 1       1      cut       0.0        c  category         5  Ideal (40.0)
# 2       2    color       0.0        c    object         7      G (20.9)
# 3       3  clarity       0.0        c    object         8    SI1 (24.2)
# 4       4    depth       0.0        n   float64       184           NaN
# 5       5    table       0.0        n   float64       127           NaN
# 6       6    price       0.0        n     int64     11602           NaN
# 7       7        x       0.0        n   float64       554           NaN
# 8       8        y       0.0        n   float64       552           NaN
# 9       9        z       0.0        n   float64       375           NaN
# 10     10   target       0.0       bn     int64         2    0.0 (65.4)
#
#                  1                 2           3  ... importance_rand  \
# 0              NaN               NaN         NaN  ...               0
# 1   Premium (25.6)  Very Good (22.4)  Good (9.1)  ...               0
# 2         E (18.2)          F (17.7)    H (15.4)  ...               0
# 3       VS2 (22.7)        SI2 (17.0)  VS1 (15.1)  ...               0
# 4              NaN               NaN         NaN  ...               0
# 5              NaN               NaN         NaN  ...               0
# 6              NaN               NaN         NaN  ...               0
# 7              NaN               NaN         NaN  ...               0
# 8              NaN               NaN         NaN  ...               0
# 9              NaN               NaN         NaN  ...               0
# 10      1.0 (34.6)               NaN         NaN  ...               0
#
#    importatnce_permut pearson  v_cramer  ratio  kendall  v_cramer_  pearson_  \
# 0                   0       1         1      1        1        NaN     -0.26
# 1                   0       1         1      1        1       0.17       NaN
# 2                   0       1         1      1        1       0.15       NaN
# 3                   0       1         1      1        1       1.00       NaN
# 4                   0       1         1      1        1        NaN     -0.05
# 5                   0       1         1      1        1        NaN     -0.12
# 6                   0       1         1      1        1        NaN     -0.11
# 7                   0       1         1      1        1        NaN     -0.28
# 8                   0       1         1      1        1        NaN     -0.27
# 9                   0       1         1      1        1        NaN     -0.28
# 10                  0       1         1      1        1       1.00      1.00
#
#     ratio_  kendall_
# 0      NaN     -0.24
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      NaN     -0.06
# 5      NaN     -0.11
# 6      NaN     -0.13
# 7      NaN     -0.23
# 8      NaN     -0.23
# 9      NaN     -0.23
# 10     NaN      1.00
#
# [11 rows x 32 columns]

# %% [markdown]
# # Analiza - pojedyncze zmienne objśniające

# %% [markdown]
# ## Kategoryczne

# %%
var_y = 'target'
var_x = 'cut'

# mozliwosc szybkiego przekodowania zmiennej kategorycznej
new_name = 'cut_new_encoding'
data = categorical_features_recoding(data = data
                                     , var = var_x
                                     , dict_old_new={'Ideal':'0','Premium':'1','Good':'2','Very Good':'3','Fair':'4'} # sloniwk co na co przekodowac
                                     , else_value = None # na jako wartosc przekodowac pozostale kategorie (Jezeli None nie sa rekodowane)
                                     , new_name = new_name # nazwa nowej zmiennej z zrekodowanymi wartosciami
                                    )

h('STATYSTYKI PO KLASACH TARGETU')
cross_tab(  data      = data
          , var_1     = var_y
          , var_2     = var_x
          , round     = 1
          , normalize = 'index')

h('KORELACJA V_CRAMERA Z TARGETEM')
correlation_cramers_v(var_1=data[var_x], var_2=data[var_y], round = 2)
# Out:
# <font size = "3"><b>STATYSTYKI PO KLASACH TARGETU</b></font>
#    count  percent  c(Fair)  c(Good)  c(Ideal)  c(Premium)  c(Very Good)  \
# 0  35258     65.4     1345     3715     12097       10086          8015
# 1  18682     34.6      265     1191      9454        3705          4067
#
#    p(Fair)  p(Good)  p(Ideal)  p(Premium)  p(Very Good)
# 0      3.8     10.5      34.3        28.6          22.7
# 1      1.4      6.4      50.6        19.8          21.8
# <font size = "3"><b>KORELACJA V_CRAMERA Z TARGETEM</b></font>
# 0.17

# %% [markdown]
# ## Numeryczne

# %%
var_y = 'target'
var_x = 'price'
var_group = 'cut'

h('STATYSTYKI')
statistics_numeric(  data      = data  # dane
                   , var_x     = var_x   # zmienne
                   , var_group = None  # zmienna gupująca (opcjonalnie)
                   , x_lim     = None  # ograniczenia na wartości zmiennej (np. żeby usunac wartosci odstajace)
                   , round     = 2)    # zaokrlaglenie liczb po przecinku

h('STATYSTYKI GRUPOWANE')
statistics_numeric(  data      = data  # dane
                   , var_x     = var_x   # zmienne
                   , var_group = var_group  # zmienna gupująca (opcjonalnie)
                   , x_lim     = None  # ograniczenia na wartości zmiennej (np. żeby usunac wartosci odstajace)
                   , round     = 2)    # zaokrlaglenie liczb po przecinku

h('ROZKŁAD GESTOŚCI')
# bez grupowanie
plot_density(  data      = data # dane     
             , var_x     = var_x # zmienna grupujaca (opcjonalnie)
             , var_group = None # zmienna
             , bw_method = 0.2  # wygladzenie rozkladu 
             , x_lim     = None # ograniczenia na wartości zmiennej (np. żeby usunac wartosci odstajace)
             , fig_w     = 12  # szerokosc wykresu
             , fig_h     = 8) # wysokosc wykresu

h('ROZKŁAD GESTOŚCI GRUPOWANY')
plot_density(  data      = data # dane     
             , var_x     = var # zmienna grupujaca (opcjonalnie)
             , var_group = var_group # zmienna
             , bw_method = 0.2  # wygladzenie rozkladu 
             , x_lim     = None # ograniczenia na wartości zmiennej (np. żeby usunac wartosci odstajace)
             , fig_w     = 12  # szerokosc wykresu
             , fig_h     = 8) # wysokosc wykresu

h('KORELACJA PEARSONA Z TARGETEM')
correlation_pearson(data=data, vars = [var_x, var_y])
# Out:
# <font size = "3"><b>STATYSTYKI</b></font>
#    min   q_05   q_10   q_25    q_50     q_75    q_90     q_95    max
# 0  326  544.0  646.0  950.0  2401.0  5324.25  9821.0  13107.1  18823
# <font size = "3"><b>STATYSTYKI GRUPOWANE</b></font>
#            min_  q_10     q_25    q_50     q_75     q_90   max_
# cut
# Fair        337  1114  2050.25  3282.0  5205.50   9133.7  18574
# Good        327   603  1145.00  3050.5  5028.00   8736.0  18788
# Ideal       326   652   878.00  1810.0  4678.50   9077.0  18806
# Premium     326   709  1046.00  3185.0  6296.00  11413.0  18823
# Very Good   336   576   912.00  2648.0  5372.75   9680.9  18818
# <font size = "3"><b>ROZKŁAD GESTOŚCI</b></font>
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# <font size = "3"><b>ROZKŁAD GESTOŚCI GRUPOWANY</b></font>
# <font size = "3"><b>KORELACJA PEARSONA Z TARGETEM</b></font>
#         price  target
# price    1.00   -0.11
# target  -0.11    1.00

# %% [markdown]
# # Analiza - korelacje między zmiennymi objaśniającymi

# %% [markdown]
# ## Kategoriczne

# %%
var_x_categorical = ['cut', 'color', 'clarity']

correlation_cramer_v_matrix(  data = data
                            , vars = var_x_categorical
                            , heatmap = True
                            , width = 10
                            , height = 10
                            , color_threshold = 0.75
                            , round = 2)

# %% [markdown]
# ## Numeryczne

# %%
var_x_numeric = ['depth', 'table', 'price', 'x', 'y', 'z']

correlation_pearson(  data = data
                    , vars = var_x_numeric
                    , heatmap = True
                    , width = 10
                    , height = 10
                    , round = 2)

# %% [markdown]
# ## Numeryczne vs kategoryczne

# %%
var_x_categorical = ['cut','color','clarity']
var_x_numeric     = ['price','table','depth','x','y','z']

correlation_ratio_matrix(  data = data
                         , vars_cat = var_x_categorical
                         , vars_num = var_x_numeric
                         , heatmap = False # obecnie funkcja nie dziala porpawnie
                         , width = 10
                         , height = 10
                         , round = 2)
# Out:
#          price  table  depth     x     y     z
# cut       0.11   0.57   0.35  0.19  0.17  0.19
# color     0.18   0.06   0.05  0.28  0.28  0.28
# clarity   0.16   0.16   0.10  0.38  0.37  0.38

# %% [markdown]
# # Analiza - korelacje targetu z zmiennymi objaśniającymi

# %% [markdown]
# ## Feature importatnce (catboost)

# %%
vax_y = 'target'
var_x = ['cut', 'color', 'clarity', 'x', 'y', 'z', 'price', 'table']
var_x_categorical = ['cut', 'color', 'clarity']

train_x = data[var_x]
train_y = data[var_y]


feature_importance_class_CB( iterations     = 30
                            , learning_rate = 0.1
                            , depth         = 5
                            , cat_features  = var_x_categorical
                            , x_train       = train_x
                            , y_train       = train_y)
# Out:
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
#   Feature Id  Importances
# 0    clarity       99.898
# 1          z        0.026
# 2      price        0.024
# 3      table        0.020
# 4          y        0.016
# 5          x        0.015
# 6        cut        0.000
# 7      color        0.000

# %% [markdown]
# # Model - binarny target

# %% [markdown]
# ## Zmienne i zbiory

# %%
# zmienne
y_var = ['target']        # zmianna objasniana
x_var_num = ['price', 'x', 'y', 'z']  # zmienne objasniajace numeryczne
x_var_cat = ['color','clarity','cut'] # zmienne objasniajace kategoryczne
x_var = x_var_num + x_var_cat         # wszystkie zmienna objasniajace

# podzial na zbioru 'data' na train i test
x_train, x_test, y_train, y_test = skl.model_selection.train_test_split(data[x_var], data[y_var], test_size=0.33)

# reset indexow na zbiorach
x_train = x_train.reset_index(drop=True)
x_test  = x_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test  = y_test.reset_index(drop=True)

# umieszczenie w jednym zbiorze zmiennych objasniajacych i zmiennej objasnianej
train_set = pd.concat([x_train, y_train], axis = 1)
test_set  = pd.concat([x_test, y_test], axis = 1)

# zamiana zmiennej objasnianej na typ 'str'
train_set[y_var] = train_set[y_var].astype(str)
test_set[y_var]  = test_set[y_var].astype(str)

# %% [markdown]
# ## Uczenie i performance

# %%
# Parametry symulacji do UCZENIA MODELI
simulation_name        = 'symulacja_1' # unikalna nazwa symulacji
simulation_description = 'pierwszy model na wszyskich zmiennych' # opis symulacji
models_list            = {'rf':models_base['rf'], 'cat':models_base['cat']} # slownik modeli do nauki wybranych z listy 'model_base'
cv_n                   = 4     # walidacja krzyzowa: ilosc k-foldow na walidacji krzyzowej (None jezeli nie chcemy walidacji krzyzowej)
hold_n                 = 4     # walidacja holdout: ilosc samplow na holdout (None jezeli nie chcemy walidacji holdout)
hold_train_sample_size = 0.1   # walidacja holdout: wielkosc losowanego zbioru train na holdout
hold_test_sample_size  = 0.1   # walidacja holdout: wielkosc losowanego zbioru test na holdout
fip_n                  = 1     # walidacja feature importatnce permutation:  ilosc samplow (None jezeli nie chcemy. Jezeli chcemy, zalecana wartosc to 1)
model_fip              = RandomForestClassifier(n_estimators=20, max_depth=7) # walidacja feature importatnce permutation: okreslenie modelu
by_var                 = 'cut' # walidacja segmentacyjna: zmienna po ktore wykonac segmentacje by_var (None jezeli nie chcemy)
pos_label              = '1'   # ktory label zmiennej objasnianej jest traktowany jako 'positive'
balancing_method       = None  # metoda balansowania (dostepne: ''over', 'under', 'None')
calibration_method     = None # metoda kalibracji prawdopodobienstwa (dostepne : 'isotonic', 'None')
cat_encoding_method    = 'target' # metoda enkodowania zmiennych kategorycznych (dostepne: 'target', 'None')

# parematry dla PERFORMANCE
threshold              = {'0':0.5, '1':0.5} # thresholdy dla kazdej kategorii (jezeli damy 'None' przypisywanie odbywa sie poprzez max(pd))


# inicjalizacja nowego obiektu do symulacji (na tym obiekcie bedziemy wykonywac kolejne symulacje, więc kolejne inicjalizacje nie sa potrzebne)
c1 = classification_model()

# UCZENIE MODELI (obliczane tylko prawdopodobienstwa)
c1.simulation(  train_set = train_set, test_set = test_set, y_var = y_var, x_var_num = x_var_num, x_var_cat = x_var_cat, by_var=by_var
              , balancing_method=balancing_method
              , cv_n=cv_n, fip_n=fip_n, hold_n = hold_n, hold_train_sample_size = hold_train_sample_size, hold_test_sample_size = hold_test_sample_size
              , data_check=True, models_list=models_list, correlation = True, model_fip = RandomForestClassifier(n_estimators=30, max_depth=7)
              , simulation_name = simulation_name, description = simulation_description)

# PERFORMANCE (na uzyskane w poprzednim kroku prawdopodobienstwa nadkladamy thresholdy i liczymy scory confusion matrix itp.)
c1.performance(simulation_name=simulation_name, threshold=threshold, priori =  None)

# zapisanie wynikow na dysk
c1.save_results(path = r'C:\Users\memy\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\results\symulacja_1', override = True)

# ladowanie z dysku do zainicjonanweg wczeniej pustego obiektu
# c1.load_results(path = '...')
# Out:
# (36139, 7)
# (17801, 7)
# (36139, 7)
# (17801, 7)
# cv 0
# 0
# (23762, 2)
# (18070, 2)
# (17801, 2)
# 1
# (23498, 2)
# (18069, 2)
# (17801, 2)
# cv 1
# 0
# (23762, 2)
# (18070, 2)
# (17801, 2)
# 1
# (23498, 2)
# (18069, 2)
# (17801, 2)
# hold 0
# (4608, 2)
# (3614, 2)
# (17801, 2)
# (4732, 2)
# (3614, 2)
# (17801, 2)
# (4794, 2)
# (3614, 2)
# (17801, 2)
# (4686, 2)
# (3614, 2)
# (17801, 2)
# hold 1
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# (4608, 2)
# (3614, 2)
# (17801, 2)
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# (4732, 2)
# (3614, 2)
# (17801, 2)
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# (4794, 2)
# (3614, 2)
# (17801, 2)
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# (4686, 2)
# (3614, 2)
# (17801, 2)
# by_var 0
# (1826, 2)
# (508, 2)
# (17801, 2)
# (4902, 2)
# (1679, 2)
# (17801, 2)
# (16314, 2)
# (7048, 2)
# (17801, 2)
# (13638, 2)
# (4465, 2)
# (17801, 2)
# (10580, 2)
# (4101, 2)
# (17801, 2)
# by_var 1
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# (1826, 2)
# (508, 2)
# (17801, 2)
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# (4902, 2)
# (1679, 2)
# (17801, 2)
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# (16314, 2)
# (7048, 2)
# (17801, 2)
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# (13638, 2)
# (4465, 2)
# (17801, 2)
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# (10580, 2)
# (4101, 2)
# (17801, 2)
# full 0
# full 1
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# feature_importance
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# fip 0
# THRESHOLD
# {'0': 0.5, '1': 0.5}
# ('symulacja_1', 'cat', 'test', 'by_var', 0, 'Fair', 0)
# ('symulacja_1', 'cat', 'test', 'by_var', 1, 'Good', 0)
# ('symulacja_1', 'cat', 'test', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1', 'cat', 'test', 'by_var', 3, 'Premium', 0)
# ('symulacja_1', 'cat', 'test', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1', 'cat', 'test', 'cv', 0, '_', 0)
# ('symulacja_1', 'cat', 'test', 'cv', 1, '_', 0)
# ('symulacja_1', 'cat', 'test', 'full', 0, '_', 0)
# ('symulacja_1', 'cat', 'test', 'hold', 0, '_', 0)
# ('symulacja_1', 'cat', 'test', 'hold', 1, '_', 0)
# ('symulacja_1', 'cat', 'test', 'hold', 2, '_', 0)
# ('symulacja_1', 'cat', 'test', 'hold', 3, '_', 0)
# ('symulacja_1', 'cat', 'train', 'by_var', 0, 'Fair', 0)
# ('symulacja_1', 'cat', 'train', 'by_var', 1, 'Good', 0)
# ('symulacja_1', 'cat', 'train', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1', 'cat', 'train', 'by_var', 3, 'Premium', 0)
# ('symulacja_1', 'cat', 'train', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1', 'cat', 'train', 'cv', 0, '_', 0)
# ('symulacja_1', 'cat', 'train', 'cv', 1, '_', 0)
# ('symulacja_1', 'cat', 'train', 'full', 0, '_', 0)
# ('symulacja_1', 'cat', 'train', 'hold', 0, '_', 0)
# ('symulacja_1', 'cat', 'train', 'hold', 1, '_', 0)
# ('symulacja_1', 'cat', 'train', 'hold', 2, '_', 0)
# ('symulacja_1', 'cat', 'train', 'hold', 3, '_', 0)
# ('symulacja_1', 'cat', 'valid', 'by_var', 0, 'Fair', 0)
# ('symulacja_1', 'cat', 'valid', 'by_var', 1, 'Good', 0)
# ('symulacja_1', 'cat', 'valid', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1', 'cat', 'valid', 'by_var', 3, 'Premium', 0)
# ('symulacja_1', 'cat', 'valid', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1', 'cat', 'valid', 'cv', 0, '_', 0)
# ('symulacja_1', 'cat', 'valid', 'cv', 1, '_', 0)
# ('symulacja_1', 'cat', 'valid', 'hold', 0, '_', 0)
# ('symulacja_1', 'cat', 'valid', 'hold', 1, '_', 0)
# ('symulacja_1', 'cat', 'valid', 'hold', 2, '_', 0)
# ('symulacja_1', 'cat', 'valid', 'hold', 3, '_', 0)
# ('symulacja_1', 'rf', 'test', 'by_var', 0, 'Fair', 0)
# ('symulacja_1', 'rf', 'test', 'by_var', 1, 'Good', 0)
# ('symulacja_1', 'rf', 'test', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1', 'rf', 'test', 'by_var', 3, 'Premium', 0)
# ('symulacja_1', 'rf', 'test', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1', 'rf', 'test', 'cv', 0, '_', 0)
# ('symulacja_1', 'rf', 'test', 'cv', 1, '_', 0)
# ('symulacja_1', 'rf', 'test', 'full', 0, '_', 0)
# ('symulacja_1', 'rf', 'test', 'hold', 0, '_', 0)
# ('symulacja_1', 'rf', 'test', 'hold', 1, '_', 0)
# ('symulacja_1', 'rf', 'test', 'hold', 2, '_', 0)
# ('symulacja_1', 'rf', 'test', 'hold', 3, '_', 0)
# ('symulacja_1', 'rf', 'train', 'by_var', 0, 'Fair', 0)
# ('symulacja_1', 'rf', 'train', 'by_var', 1, 'Good', 0)
# ('symulacja_1', 'rf', 'train', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1', 'rf', 'train', 'by_var', 3, 'Premium', 0)
# ('symulacja_1', 'rf', 'train', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1', 'rf', 'train', 'cv', 0, '_', 0)
# ('symulacja_1', 'rf', 'train', 'cv', 1, '_', 0)
# ('symulacja_1', 'rf', 'train', 'full', 0, '_', 0)
# ('symulacja_1', 'rf', 'train', 'hold', 0, '_', 0)
# ('symulacja_1', 'rf', 'train', 'hold', 1, '_', 0)
# ('symulacja_1', 'rf', 'train', 'hold', 2, '_', 0)
# ('symulacja_1', 'rf', 'train', 'hold', 3, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'by_var', 0, 'Fair', 0)
# ('symulacja_1', 'rf', 'valid', 'by_var', 1, 'Good', 0)
# ('symulacja_1', 'rf', 'valid', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1', 'rf', 'valid', 'by_var', 3, 'Premium', 0)
# ('symulacja_1', 'rf', 'valid', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1', 'rf', 'valid', 'cv', 0, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'cv', 1, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'hold', 0, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'hold', 1, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'hold', 2, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'hold', 3, '_', 0)

# %% [markdown]
# ## Wizualiacja wynikow

# %%
h('meta informations about simulation')
c1.simulation_metainfo.loc[c1.simulation_metainfo['simulation_name'] == simulation_name]
h('correlation between features')
c1.fast_correlation_matrices(simulation_name = simulation_name)
h('target distribution, confussion matrix, scores and feature importance')
c1.fast_conf_matrix_scores(simulation_name = simulation_name)
h('density plots')
c1.fast_dens_plot(simulation_name=simulation_name, sample_type = ['full'])
h('density plot for Feature Importatnce Permutation')
c1.fast_dens_plot(simulation_name=simulation_name, sample_type = ['fip'])
h('scores by cross validation')
c1.fast_scores_plot(simulation_name=simulation_name, sample_type = 'cv')
h('scores by holdout')
c1.fast_scores_plot(simulation_name=simulation_name, sample_type = 'hold')
if by_var is not None:
    h('scores by by_var')
    c1.fast_scores_plot(simulation_name=simulation_name, sample_type = 'by_var')
h('pr and roc curve')
c1.plot_roc_pr_curves(simulation_name=simulation_name, set_type='test', sample_type = ['full'], y_category=pos_label)
h('pr and roc curve for Feature Importatnce Permutation')
c1.plot_roc_pr_curves(simulation_name=simulation_name, set_type='test', sample_type = ['fip', 'full'], y_category=pos_label, group = 'model_name', facet = 'sample_nr~variable')
# Out:
# <font size = "3"><b>meta informations about simulation</b></font>
#   simulation_name                            description  x_n  y_name  \
# 0     symulacja_1  pierwszy model na wszyskich zmiennych    5  target
#
#   y_labels           x_num  x_cat cat_encoding balancing calibration  \
# 0     0, 1  price, x, y, z  color       target      over        None
#
#       simulation_start       simulation_end pos_label priori  \
# 0  2020-06-11 22:42:11  2020-06-11 22:43:03         1   None
#
#               threshold    performance start      performance end
# 0  {'0': 0.5, '1': 0.5}  2020-06-11 22:43:03  2020-06-11 22:43:40
# <font size = "3"><b>correlation between features</b></font>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_b0beed70_ac24_11ea_9104_985fd3cf311a" style='display:inline'><caption>pearson</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>        <th class="col_heading level0 col1" >x</th>        <th class="col_heading level0 col2" >y</th>        <th class="col_heading level0 col3" >z</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0beed70_ac24_11ea_9104_985fd3cf311alevel0_row0" class="row_heading level0 row0" >price</th>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow0_col1" class="data row0 col1" >0.890</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow0_col2" class="data row0 col2" >0.860</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow0_col3" class="data row0 col3" >0.880</td>
#             </tr>
#             <tr>
#                         <th id="T_b0beed70_ac24_11ea_9104_985fd3cf311alevel0_row1" class="row_heading level0 row1" >x</th>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow1_col0" class="data row1 col0" >0.890</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow1_col2" class="data row1 col2" >0.970</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow1_col3" class="data row1 col3" >0.990</td>
#             </tr>
#             <tr>
#                         <th id="T_b0beed70_ac24_11ea_9104_985fd3cf311alevel0_row2" class="row_heading level0 row2" >y</th>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow2_col0" class="data row2 col0" >0.860</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow2_col1" class="data row2 col1" >0.970</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow2_col3" class="data row2 col3" >0.960</td>
#             </tr>
#             <tr>
#                         <th id="T_b0beed70_ac24_11ea_9104_985fd3cf311alevel0_row3" class="row_heading level0 row3" >z</th>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow3_col0" class="data row3 col0" >0.880</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow3_col1" class="data row3 col1" >0.990</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow3_col2" class="data row3 col2" >0.960</td>
#                         <td id="T_b0beed70_ac24_11ea_9104_985fd3cf311arow3_col3" class="data row3 col3" >1.000</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311a" style='display:inline'><caption>kendall</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>        <th class="col_heading level0 col1" >x</th>        <th class="col_heading level0 col2" >y</th>        <th class="col_heading level0 col3" >z</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311alevel0_row0" class="row_heading level0 row0" >price</th>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow0_col1" class="data row0 col1" >0.830</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow0_col2" class="data row0 col2" >0.830</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow0_col3" class="data row0 col3" >0.820</td>
#             </tr>
#             <tr>
#                         <th id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311alevel0_row1" class="row_heading level0 row1" >x</th>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow1_col0" class="data row1 col0" >0.830</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow1_col2" class="data row1 col2" >0.970</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow1_col3" class="data row1 col3" >0.910</td>
#             </tr>
#             <tr>
#                         <th id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311alevel0_row2" class="row_heading level0 row2" >y</th>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow2_col0" class="data row2 col0" >0.830</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow2_col1" class="data row2 col1" >0.970</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow2_col3" class="data row2 col3" >0.910</td>
#             </tr>
#             <tr>
#                         <th id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311alevel0_row3" class="row_heading level0 row3" >z</th>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow3_col0" class="data row3 col0" >0.820</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow3_col1" class="data row3 col1" >0.910</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow3_col2" class="data row3 col2" >0.910</td>
#                         <td id="T_b0bf6224_ac24_11ea_b2b5_985fd3cf311arow3_col3" class="data row3 col3" >1.000</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b0bfb012_ac24_11ea_8000_985fd3cf311a" style='display:inline'><caption>ratio</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>        <th class="col_heading level0 col1" >x</th>        <th class="col_heading level0 col2" >y</th>        <th class="col_heading level0 col3" >z</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0bfb012_ac24_11ea_8000_985fd3cf311alevel0_row0" class="row_heading level0 row0" >color</th>
#                         <td id="T_b0bfb012_ac24_11ea_8000_985fd3cf311arow0_col0" class="data row0 col0" >0.170</td>
#                         <td id="T_b0bfb012_ac24_11ea_8000_985fd3cf311arow0_col1" class="data row0 col1" >0.280</td>
#                         <td id="T_b0bfb012_ac24_11ea_8000_985fd3cf311arow0_col2" class="data row0 col2" >0.270</td>
#                         <td id="T_b0bfb012_ac24_11ea_8000_985fd3cf311arow0_col3" class="data row0 col3" >0.280</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b0bfd740_ac24_11ea_a737_985fd3cf311a" style='display:inline'><caption>v_cramer</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >color</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0bfd740_ac24_11ea_a737_985fd3cf311alevel0_row0" class="row_heading level0 row0" >color</th>
#                         <td id="T_b0bfd740_ac24_11ea_a737_985fd3cf311arow0_col0" class="data row0 col0" >1.000</td>
#             </tr>
#     </tbody></table>
# <font size = "3"><b>target distribution, confussion matrix, scores and feature importance</b></font>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_b0d5e7fe_ac24_11ea_9c06_985fd3cf311a" style='display:inline'><caption>target train</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >target</th>        <th class="col_heading level0 col2" >proc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0d5e7fe_ac24_11ea_9c06_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0d5e7fe_ac24_11ea_9c06_985fd3cf311arow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_b0d5e7fe_ac24_11ea_9c06_985fd3cf311arow0_col1" class="data row0 col1" >23630</td>
#                         <td id="T_b0d5e7fe_ac24_11ea_9c06_985fd3cf311arow0_col2" class="data row0 col2" >65.390</td>
#             </tr>
#             <tr>
#                         <th id="T_b0d5e7fe_ac24_11ea_9c06_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0d5e7fe_ac24_11ea_9c06_985fd3cf311arow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_b0d5e7fe_ac24_11ea_9c06_985fd3cf311arow1_col1" class="data row1 col1" >12509</td>
#                         <td id="T_b0d5e7fe_ac24_11ea_9c06_985fd3cf311arow1_col2" class="data row1 col2" >34.610</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b0d65ce4_ac24_11ea_8816_985fd3cf311a" style='display:inline'><caption>target test</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >target</th>        <th class="col_heading level0 col2" >proc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0d65ce4_ac24_11ea_8816_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0d65ce4_ac24_11ea_8816_985fd3cf311arow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_b0d65ce4_ac24_11ea_8816_985fd3cf311arow0_col1" class="data row0 col1" >11628</td>
#                         <td id="T_b0d65ce4_ac24_11ea_8816_985fd3cf311arow0_col2" class="data row0 col2" >65.320</td>
#             </tr>
#             <tr>
#                         <th id="T_b0d65ce4_ac24_11ea_8816_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0d65ce4_ac24_11ea_8816_985fd3cf311arow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_b0d65ce4_ac24_11ea_8816_985fd3cf311arow1_col1" class="data row1 col1" >6173</td>
#                         <td id="T_b0d65ce4_ac24_11ea_8816_985fd3cf311arow1_col2" class="data row1 col2" >34.680</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b0d6f91e_ac24_11ea_b473_985fd3cf311a" style='display:inline'><caption>thresholds</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0d6f91e_ac24_11ea_b473_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0d6f91e_ac24_11ea_b473_985fd3cf311arow0_col0" class="data row0 col0" >0.500</td>
#             </tr>
#             <tr>
#                         <th id="T_b0d6f91e_ac24_11ea_b473_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0d6f91e_ac24_11ea_b473_985fd3cf311arow1_col0" class="data row1 col0" >0.500</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311a" style='display:inline'><caption>Confusion matrix  TRAIN ,   Model:  cat</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >_sum_</th>        <th class="col_heading level0 col3" >_correctness_</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow0_col0" class="data row0 col0" >18600</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow0_col1" class="data row0 col1" >5030</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow0_col2" class="data row0 col2" >23630</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow0_col3" class="data row0 col3" >78</td>
#             </tr>
#             <tr>
#                         <th id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow1_col0" class="data row1 col0" >4200</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow1_col1" class="data row1 col1" >19430</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow1_col2" class="data row1 col2" >23630</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow1_col3" class="data row1 col3" >82</td>
#             </tr>
#             <tr>
#                         <th id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311alevel0_row2" class="row_heading level0 row2" >_sum_</th>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow2_col0" class="data row2 col0" >22800</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow2_col1" class="data row2 col1" >24460</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow2_col2" class="data row2 col2" >0</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow2_col3" class="data row2 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311alevel0_row3" class="row_heading level0 row3" >_correctness_</th>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow3_col0" class="data row3 col0" >81</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow3_col1" class="data row3 col1" >79</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow3_col2" class="data row3 col2" >0</td>
#                         <td id="T_b0d968d0_ac24_11ea_ae41_985fd3cf311arow3_col3" class="data row3 col3" >0</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b0da78c0_ac24_11ea_8645_985fd3cf311a" style='display:inline'><caption>Confusion matrix  TRAIN ,   Model:  rf</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >_sum_</th>        <th class="col_heading level0 col3" >_correctness_</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0da78c0_ac24_11ea_8645_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow0_col0" class="data row0 col0" >19292</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow0_col1" class="data row0 col1" >4338</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow0_col2" class="data row0 col2" >23630</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_b0da78c0_ac24_11ea_8645_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow1_col0" class="data row1 col0" >4910</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow1_col1" class="data row1 col1" >18720</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow1_col2" class="data row1 col2" >23630</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow1_col3" class="data row1 col3" >79</td>
#             </tr>
#             <tr>
#                         <th id="T_b0da78c0_ac24_11ea_8645_985fd3cf311alevel0_row2" class="row_heading level0 row2" >_sum_</th>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow2_col0" class="data row2 col0" >24202</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow2_col1" class="data row2 col1" >23058</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow2_col2" class="data row2 col2" >0</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow2_col3" class="data row2 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_b0da78c0_ac24_11ea_8645_985fd3cf311alevel0_row3" class="row_heading level0 row3" >_correctness_</th>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow3_col0" class="data row3 col0" >79</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow3_col1" class="data row3 col1" >81</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow3_col2" class="data row3 col2" >0</td>
#                         <td id="T_b0da78c0_ac24_11ea_8645_985fd3cf311arow3_col3" class="data row3 col3" >0</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311a" style='display:inline'><caption>Confusion matrix  TEST,    Model:  cat</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >_sum_</th>        <th class="col_heading level0 col3" >_correctness_</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow0_col0" class="data row0 col0" >9108</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow0_col1" class="data row0 col1" >2520</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow0_col2" class="data row0 col2" >11628</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow0_col3" class="data row0 col3" >78</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow1_col0" class="data row1 col0" >1143</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow1_col1" class="data row1 col1" >5030</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow1_col2" class="data row1 col2" >6173</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow1_col3" class="data row1 col3" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311alevel0_row2" class="row_heading level0 row2" >_sum_</th>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow2_col0" class="data row2 col0" >10251</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow2_col1" class="data row2 col1" >7550</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow2_col2" class="data row2 col2" >0</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow2_col3" class="data row2 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311alevel0_row3" class="row_heading level0 row3" >_correctness_</th>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow3_col0" class="data row3 col0" >88</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow3_col1" class="data row3 col1" >66</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow3_col2" class="data row3 col2" >0</td>
#                         <td id="T_b0dbd75e_ac24_11ea_bc68_985fd3cf311arow3_col3" class="data row3 col3" >0</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311a" style='display:inline'><caption>Confusion matrix  TEST,    Model:  rf</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >_sum_</th>        <th class="col_heading level0 col3" >_correctness_</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow0_col0" class="data row0 col0" >9451</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow0_col1" class="data row0 col1" >2177</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow0_col2" class="data row0 col2" >11628</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow1_col0" class="data row1 col0" >1375</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow1_col1" class="data row1 col1" >4798</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow1_col2" class="data row1 col2" >6173</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow1_col3" class="data row1 col3" >77</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311alevel0_row2" class="row_heading level0 row2" >_sum_</th>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow2_col0" class="data row2 col0" >10826</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow2_col1" class="data row2 col1" >6975</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow2_col2" class="data row2 col2" >0</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow2_col3" class="data row2 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311alevel0_row3" class="row_heading level0 row3" >_correctness_</th>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow3_col0" class="data row3 col0" >87</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow3_col1" class="data row3 col1" >68</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow3_col2" class="data row3 col2" >0</td>
#                         <td id="T_b0dc2546_ac24_11ea_ab52_985fd3cf311arow3_col3" class="data row3 col3" >0</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311a" style='display:inline'><caption>score: accuracy</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow0_col0" class="data row0 col0" >cat</td>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow0_col2" class="data row0 col2" >0.794</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow1_col0" class="data row1 col0" >cat</td>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow1_col1" class="data row1 col1" >train</td>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow1_col2" class="data row1 col2" >0.805</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow2_col0" class="data row2 col0" >rf</td>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow2_col1" class="data row2 col1" >test</td>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow2_col2" class="data row2 col2" >0.800</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow3_col0" class="data row3 col0" >rf</td>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow3_col1" class="data row3 col1" >train</td>
#                         <td id="T_b0dd5d26_ac24_11ea_af98_985fd3cf311arow3_col2" class="data row3 col2" >0.804</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311a" style='display:inline'><caption>score: balanced_accuracy</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow0_col0" class="data row0 col0" >cat</td>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow0_col2" class="data row0 col2" >0.799</td>
#             </tr>
#             <tr>
#                         <th id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow1_col0" class="data row1 col0" >cat</td>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow1_col1" class="data row1 col1" >train</td>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow1_col2" class="data row1 col2" >0.805</td>
#             </tr>
#             <tr>
#                         <th id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow2_col0" class="data row2 col0" >rf</td>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow2_col1" class="data row2 col1" >test</td>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow2_col2" class="data row2 col2" >0.795</td>
#             </tr>
#             <tr>
#                         <th id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow3_col0" class="data row3 col0" >rf</td>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow3_col1" class="data row3 col1" >train</td>
#                         <td id="T_b0ddafd4_ac24_11ea_95c0_985fd3cf311arow3_col2" class="data row3 col2" >0.804</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311a" style='display:inline'><caption>score: recall</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow0_col0" class="data row0 col0" >cat</td>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow0_col2" class="data row0 col2" >0.815</td>
#             </tr>
#             <tr>
#                         <th id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow1_col0" class="data row1 col0" >cat</td>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow1_col1" class="data row1 col1" >train</td>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow1_col2" class="data row1 col2" >0.822</td>
#             </tr>
#             <tr>
#                         <th id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow2_col0" class="data row2 col0" >rf</td>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow2_col1" class="data row2 col1" >test</td>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow2_col2" class="data row2 col2" >0.777</td>
#             </tr>
#             <tr>
#                         <th id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow3_col0" class="data row3 col0" >rf</td>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow3_col1" class="data row3 col1" >train</td>
#                         <td id="T_b0ddf8ca_ac24_11ea_a701_985fd3cf311arow3_col2" class="data row3 col2" >0.792</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_b0de46b8_ac24_11ea_b5ac_985fd3cf311a" style='display:inline'><caption>score: precision</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0de46b8_ac24_11ea_b5ac_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0de46b8_ac24_11ea_b5ac_985fd3cf311arow0_col0" class="data row0 col0" >cat</td>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311a" style='display:inline'><caption>Feature Importance e-net</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Importance</th>        <th class="col_heading level0 col2" >Importance_abs</th>        <th class="col_heading level0 col3" >l1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow0_col0" class="data row0 col0" >x</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow0_col1" class="data row0 col1" >-1.820</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow0_col2" class="data row0 col2" >1.820</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow0_col3" class="data row0 col3" >0.1</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow1_col0" class="data row1 col0" >price</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow1_col1" class="data row1 col1" >1.790</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow1_col2" class="data row1 col2" >1.790</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow1_col3" class="data row1 col3" >0.1</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow2_col0" class="data row2 col0" >z</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow2_col1" class="data row2 col1" >-0.710</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow2_col2" class="data row2 col2" >0.710</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow2_col3" class="data row2 col3" >0.1</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow3_col0" class="data row3 col0" >color</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow3_col1" class="data row3 col1" >0.370</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow3_col2" class="data row3 col2" >0.370</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow3_col3" class="data row3 col3" >0.1</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow4_col0" class="data row4 col0" >y</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow4_col1" class="data row4 col1" >0.300</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow4_col2" class="data row4 col2" >0.300</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow4_col3" class="data row4 col3" >0.1</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow5_col0" class="data row5 col0" >NOISE_uniform</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow5_col1" class="data row5 col1" >0.080</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow5_col2" class="data row5 col2" >0.080</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow5_col3" class="data row5 col3" >0.1</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow6_col0" class="data row6 col0" >NOISE_normal</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow6_col1" class="data row6 col1" >0.000</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow6_col2" class="data row6 col2" >0.000</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow6_col3" class="data row6 col3" >0.1</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow7_col0" class="data row7 col0" >price</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow7_col1" class="data row7 col1" >1.840</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow7_col2" class="data row7 col2" >1.840</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow7_col3" class="data row7 col3" >0.5</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow8_col0" class="data row8 col0" >x</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow8_col1" class="data row8 col1" >-1.730</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow8_col2" class="data row8 col2" >1.730</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow8_col3" class="data row8 col3" >0.5</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow9_col0" class="data row9 col0" >z</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow9_col1" class="data row9 col1" >-0.760</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow9_col2" class="data row9 col2" >0.760</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow9_col3" class="data row9 col3" >0.5</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow10_col0" class="data row10 col0" >color</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow10_col1" class="data row10 col1" >0.290</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow10_col2" class="data row10 col2" >0.290</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow10_col3" class="data row10 col3" >0.5</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311alevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow11_col0" class="data row11 col0" >y</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow11_col1" class="data row11 col1" >0.280</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow11_col2" class="data row11 col2" >0.280</td>
#                         <td id="T_b0e0681a_ac24_11ea_8c27_985fd3cf311arow11_col3" class="data row11 col3" >0.5</td>
#             </tr>
#             <tr>
#                         <th id="T_b0e0681a_ac24_11ea_8c27_9
# [None,
#  None,
#  None,
#  None,
#  None,
#  'recall = TP / TP + FN;   precision = TP / (TP + FP);    f1 = ( 2*TP ) / (2*TP + FP + FN );   balanced_accuracy = (TP/(TP+FN) + TN/(TN+FP)) / 2 ']
# <font size = "3"><b>density plots</b></font>
# <ggplot: (-9223371926254936071)>
# <ggplot: (-9223371926254930849)>
# <font size = "3"><b>density plot for Feature Importatnce Permutation</b></font>
# <ggplot: (110666005512)>
# <ggplot: (110641201654)>
# <font size = "3"><b>scores by cross validation</b></font>
# <ggplot: (-9223371926255716555)>
# <ggplot: (-9223371926188801108)>
# <font size = "3"><b>scores by holdout</b></font>
# <ggplot: (110597310156)>
# <ggplot: (-9223371926257294199)>
# <font size = "3"><b>scores by by_var</b></font>
# <ggplot: (110664931269)>
# <ggplot: (110666191613)>
# <font size = "3"><b>pr and roc curve</b></font>
# rf
# cat
# <ggplot: (-9223371926259306324)>
# <ggplot: (-9223371926189772123)>
#              average_precision
# rf - 0 - 1               0.806
# cat - 0 - 1              0.803
#              roc_auc
# cat - 0 - 1    0.877
# rf - 0 - 1     0.873
# <font size = "3"><b>pr and roc curve for Feature Importatnce Permutation</b></font>
# rf
# cat
# price
# x
# y
# z
# color
# <ggplot: (110595941794)>
# <ggplot: (-9223371926258833997)>
#                average_precision
# y - 0 - 1                  0.829
# x - 0 - 1                  0.819
# z - 0 - 1                  0.814
# rf - 0 - 1                 0.806
# cat - 0 - 1                0.803
# color - 0 - 1              0.775
# price - 0 - 1              0.595
#                roc_auc
# y - 0 - 1        0.890
# x - 0 - 1        0.882
# z - 0 - 1        0.882
# cat - 0 - 1      0.877
# rf - 0 - 1       0.873
# color - 0 - 1    0.854
# price - 0 - 1    0.734

# %% [markdown]
# ## Performance rozne thresholdy stałe - tylko model binarny

# %% [markdown]
# ## Performance rozne thresholdy qwantyle prawdop. - tylko model binarny

# %% [markdown]
# # Model - wielostanowy target

# %% [markdown]
# ## Zmienne i zbiory

# %%
# zmienne
y_var = ['target_multi_label']        # zmianna objasniana
x_var_num = ['price', 'x', 'y', 'z']  # zmienne objasniajace numeryczne
x_var_cat = ['color','clarity','cut'] # zmienne objasniajace kategoryczne
x_var = x_var_num + x_var_cat         # wszystkie zmienna objasniajace

# podzial na zbioru 'data' na train i test
x_train, x_test, y_train, y_test = skl.model_selection.train_test_split(data[x_var], data[y_var], test_size=0.33)

# reset indexow na zbiorach
x_train = x_train.reset_index(drop=True)
x_test  = x_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test  = y_test.reset_index(drop=True)

# umieszczenie w jednym zbiorze zmiennych objasniajacych i zmiennej objasnianej
train_set = pd.concat([x_train, y_train], axis = 1)
test_set  = pd.concat([x_test, y_test], axis = 1)

# zamiana zmiennej objasnianej na typ 'str'
train_set[y_var] = train_set[y_var].astype(str)
test_set[y_var]  = test_set[y_var].astype(str)

# %% [markdown]
# ## Uczenie i performance

# %%
# Parametry symulacji do UCZENIA MODELI
simulation_name        = 'symulacja_1' # unikalna nazwa symulacji
simulation_description = 'pierwszy model na wszyskich zmiennych' # opis symulacji
models_list            = {'rf':models_base['rf'], 'cat':models_base['cat']} # slownik modeli do nauki wybranych z listy 'model_base'
cv_n                   = 4     # walidacja krzyzowa: ilosc k-foldow na walidacji krzyzowej (None jezeli nie chcemy walidacji krzyzowej)
hold_n                 = 4     # walidacja holdout: ilosc samplow na holdout (None jezeli nie chcemy walidacji holdout)
hold_train_sample_size = 0.1   # walidacja holdout: wielkosc losowanego zbioru train na holdout
hold_test_sample_size  = 0.1   # walidacja holdout: wielkosc losowanego zbioru test na holdout
fip_n                  = 1     # walidacja feature importatnce permutation:  ilosc samplow (None jezeli nie chcemy. Jezeli chcemy, zalecana wartosc to 1)
model_fip              = RandomForestClassifier(n_estimators=20, max_depth=7) # walidacja feature importatnce permutation: okreslenie modelu
by_var                 = 'cut' # walidacja segmentacyjna: zmienna po ktore wykonac segmentacje by_var (None jezeli nie chcemy)
pos_label              = '1'   # ktory label zmiennej objasnianej jest traktowany jako 'positive'
balancing_method       = None  # dla modeli wieloklasowych niedostepne
calibration_method     = None # metoda kalibracji prawdopodobienstwa (dostepne : 'isotonic', 'None')
cat_encoding_method    = 'target' # metoda enkodowania zmiennych kategorycznych (dostepne: 'target', 'None')

# parematry dla PERFORMANCE (dla zagadnienie wialostenowego nie ma thresholdow. Jest tylko wazenie priori gdzie wagu sumuja sie do wartosci 1)
priori              = {'0':0.1, '1':0.3, '2':0.2, '3':0.2, '4':0.2} # thresholdy dla kazdej kategorii (jezeli damy 'None' przypisywanie odbywa sie poprzez max(pd))


# inicjalizacja nowego obiektu do symulacji (na tym obiekcie bedziemy wykonywac kolejne symulacje, więc kolejne inicjalizacje nie sa potrzebne)
c1 = classification_model()

# UCZENIE MODELI (obliczane tylko prawdopodobienstwa)
c1.simulation(  train_set = train_set, test_set = test_set, y_var = y_var, x_var_num = x_var_num, x_var_cat = x_var_cat, by_var=by_var
              , balancing_method=balancing_method
              , cv_n=cv_n, fip_n=fip_n, hold_n = hold_n, hold_train_sample_size = hold_train_sample_size, hold_test_sample_size = hold_test_sample_size
              , data_check=True, models_list=models_list, correlation = True, model_fip = RandomForestClassifier(n_estimators=30, max_depth=7)
              , simulation_name = simulation_name, description = simulation_description)

# PERFORMANCE (na uzyskane w poprzednim kroku prawdopodobienstwa nadkladamy thresholdy i liczymy scory confusion matrix itp.)
c1.performance(simulation_name=simulation_name, threshold=None, priori =  priori)

# zapisanie wynikow na dysk
c1.save_results(path = r'C:\Users\memy\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\results\symulacja_1', override = True)

# ladowanie z dysku do zainicjonanweg wczeniej pustego obiektu
# c1.load_results(path = '...')
# Out:
# (36139, 7)
# (17801, 7)
# (36139, 7)
# (17801, 7)
# cv 0
# 0
# (18069, 5)
# (18070, 5)
# (17801, 5)
# 1
# (18070, 5)
# (18069, 5)
# (17801, 5)
# hold 0
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# by_var 0
# (1114, 1)
# (496, 1)
# (17801, 1)
# (3326, 1)
# (1580, 1)
# (17801, 1)
# (14360, 1)
# (7191, 1)
# (17801, 1)
# (9213, 1)
# (4578, 1)
# (17801, 1)
# (8126, 1)
# (3956, 1)
# (17801, 1)
# full 0
# feature_importance
# fip 0
# THRESHOLD
# {'0': 0.5, '1': 0.5}
# ('symulacja_1', 'rf', 'test', 'by_var', 0, 'Fair', 0)
# ('symulacja_1', 'rf', 'test', 'by_var', 1, 'Good', 0)
# ('symulacja_1', 'rf', 'test', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1', 'rf', 'test', 'by_var', 3, 'Premium', 0)
# ('symulacja_1', 'rf', 'test', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1', 'rf', 'test', 'cv', 0, '_', 0)
# ('symulacja_1', 'rf', 'test', 'cv', 1, '_', 0)
# ('symulacja_1', 'rf', 'test', 'full', 0, '_', 0)
# ('symulacja_1', 'rf', 'test', 'hold', 0, '_', 0)
# ('symulacja_1', 'rf', 'test', 'hold', 1, '_', 0)
# ('symulacja_1', 'rf', 'test', 'hold', 2, '_', 0)
# ('symulacja_1', 'rf', 'test', 'hold', 3, '_', 0)
# ('symulacja_1', 'rf', 'train', 'by_var', 0, 'Fair', 0)
# ('symulacja_1', 'rf', 'train', 'by_var', 1, 'Good', 0)
# ('symulacja_1', 'rf', 'train', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1', 'rf', 'train', 'by_var', 3, 'Premium', 0)
# ('symulacja_1', 'rf', 'train', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1', 'rf', 'train', 'cv', 0, '_', 0)
# ('symulacja_1', 'rf', 'train', 'cv', 1, '_', 0)
# ('symulacja_1', 'rf', 'train', 'full', 0, '_', 0)
# ('symulacja_1', 'rf', 'train', 'hold', 0, '_', 0)
# ('symulacja_1', 'rf', 'train', 'hold', 1, '_', 0)
# ('symulacja_1', 'rf', 'train', 'hold', 2, '_', 0)
# ('symulacja_1', 'rf', 'train', 'hold', 3, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'by_var', 0, 'Fair', 0)
# ('symulacja_1', 'rf', 'valid', 'by_var', 1, 'Good', 0)
# ('symulacja_1', 'rf', 'valid', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1', 'rf', 'valid', 'by_var', 3, 'Premium', 0)
# ('symulacja_1', 'rf', 'valid', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1', 'rf', 'valid', 'cv', 0, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'cv', 1, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'hold', 0, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'hold', 1, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'hold', 2, '_', 0)
# ('symulacja_1', 'rf', 'valid', 'hold', 3, '_', 0)

# %% [markdown]
# ## Wizualizacja

# %%
h('meta informations about simulation')
c1.simulation_metainfo.loc[c1.simulation_metainfo['simulation_name'] == simulation_name]
h('correlation between features')
c1.fast_correlation_matrices(simulation_name = simulation_name)
h('target distribution, confussion matrix, scores and feature importance')
c1.fast_conf_matrix_scores(simulation_name = simulation_name)
h('density plots')
c1.fast_dens_plot(simulation_name=simulation_name, sample_type = ['full'])
h('density plot for Feature Importatnce Permutation')
c1.fast_dens_plot(simulation_name=simulation_name, sample_type = ['fip'])
h('scores by cross validation')
c1.fast_scores_plot(simulation_name=simulation_name, sample_type = 'cv')
h('scores by holdout')
c1.fast_scores_plot(simulation_name=simulation_name, sample_type = 'hold')
if by_var is not None:
    h('scores by by_var - segmentation validataion')
    c1.fast_scores_plot(simulation_name=simulation_name, sample_type = 'by_var')
h('pr and roc curve')
c1.plot_roc_pr_curves(simulation_name=simulation_name, set_type='test', sample_type = ['full'], y_category=pos_label)
h('pr and roc curve for Feature Importatnce Permutation')
c1.plot_roc_pr_curves(simulation_name=simulation_name, set_type='test', sample_type = ['fip', 'full'], y_category=pos_label, group = 'model_name', facet = 'sample_nr~variable')
# Out:
# <font size = "3"><b>meta informations about simulation</b></font>
#   simulation_name                            description  x_n  \
# 0     symulacja_1  pierwszy model na wszyskich zmiennych    5
#
#                y_name       y_labels           x_num  x_cat cat_encoding  \
# 0  target_multi_label  0, 1, 2, 3, 4  price, x, y, z  color       target
#
#   balancing calibration     simulation_start       simulation_end pos_label  \
# 0      None        None  2020-06-12 12:39:32  2020-06-12 12:39:53         1
#
#   priori             threshold    performance start      performance end
# 0   None  {'0': 0.5, '1': 0.5}  2020-06-12 12:39:53  2020-06-12 12:40:17
# <font size = "3"><b>correlation between features</b></font>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311a" style='display:inline'><caption>pearson</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>        <th class="col_heading level0 col1" >x</th>        <th class="col_heading level0 col2" >y</th>        <th class="col_heading level0 col3" >z</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311alevel0_row0" class="row_heading level0 row0" >price</th>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow0_col1" class="data row0 col1" >0.880</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow0_col2" class="data row0 col2" >0.850</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow0_col3" class="data row0 col3" >0.850</td>
#             </tr>
#             <tr>
#                         <th id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311alevel0_row1" class="row_heading level0 row1" >x</th>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow1_col0" class="data row1 col0" >0.880</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow1_col2" class="data row1 col2" >0.960</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow1_col3" class="data row1 col3" >0.960</td>
#             </tr>
#             <tr>
#                         <th id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311alevel0_row2" class="row_heading level0 row2" >y</th>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow2_col0" class="data row2 col0" >0.850</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow2_col1" class="data row2 col1" >0.960</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow2_col3" class="data row2 col3" >0.940</td>
#             </tr>
#             <tr>
#                         <th id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311alevel0_row3" class="row_heading level0 row3" >z</th>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow3_col0" class="data row3 col0" >0.850</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow3_col1" class="data row3 col1" >0.960</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow3_col2" class="data row3 col2" >0.940</td>
#                         <td id="T_429ff4ac_ac99_11ea_ab29_985fd3cf311arow3_col3" class="data row3 col3" >1.000</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42a09080_ac99_11ea_99e1_985fd3cf311a" style='display:inline'><caption>kendall</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>        <th class="col_heading level0 col1" >x</th>        <th class="col_heading level0 col2" >y</th>        <th class="col_heading level0 col3" >z</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42a09080_ac99_11ea_99e1_985fd3cf311alevel0_row0" class="row_heading level0 row0" >price</th>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow0_col1" class="data row0 col1" >0.830</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow0_col2" class="data row0 col2" >0.830</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow0_col3" class="data row0 col3" >0.820</td>
#             </tr>
#             <tr>
#                         <th id="T_42a09080_ac99_11ea_99e1_985fd3cf311alevel0_row1" class="row_heading level0 row1" >x</th>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow1_col0" class="data row1 col0" >0.830</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow1_col2" class="data row1 col2" >0.970</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow1_col3" class="data row1 col3" >0.910</td>
#             </tr>
#             <tr>
#                         <th id="T_42a09080_ac99_11ea_99e1_985fd3cf311alevel0_row2" class="row_heading level0 row2" >y</th>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow2_col0" class="data row2 col0" >0.830</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow2_col1" class="data row2 col1" >0.970</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow2_col3" class="data row2 col3" >0.910</td>
#             </tr>
#             <tr>
#                         <th id="T_42a09080_ac99_11ea_99e1_985fd3cf311alevel0_row3" class="row_heading level0 row3" >z</th>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow3_col0" class="data row3 col0" >0.820</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow3_col1" class="data row3 col1" >0.910</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow3_col2" class="data row3 col2" >0.910</td>
#                         <td id="T_42a09080_ac99_11ea_99e1_985fd3cf311arow3_col3" class="data row3 col3" >1.000</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42a12c50_ac99_11ea_95e7_985fd3cf311a" style='display:inline'><caption>ratio</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>        <th class="col_heading level0 col1" >x</th>        <th class="col_heading level0 col2" >y</th>        <th class="col_heading level0 col3" >z</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42a12c50_ac99_11ea_95e7_985fd3cf311alevel0_row0" class="row_heading level0 row0" >color</th>
#                         <td id="T_42a12c50_ac99_11ea_95e7_985fd3cf311arow0_col0" class="data row0 col0" >0.180</td>
#                         <td id="T_42a12c50_ac99_11ea_95e7_985fd3cf311arow0_col1" class="data row0 col1" >0.280</td>
#                         <td id="T_42a12c50_ac99_11ea_95e7_985fd3cf311arow0_col2" class="data row0 col2" >0.270</td>
#                         <td id="T_42a12c50_ac99_11ea_95e7_985fd3cf311arow0_col3" class="data row0 col3" >0.280</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42a17a3a_ac99_11ea_85fb_985fd3cf311a" style='display:inline'><caption>v_cramer</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >color</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42a17a3a_ac99_11ea_85fb_985fd3cf311alevel0_row0" class="row_heading level0 row0" >color</th>
#                         <td id="T_42a17a3a_ac99_11ea_85fb_985fd3cf311arow0_col0" class="data row0 col0" >1.000</td>
#             </tr>
#     </tbody></table>
# <font size = "3"><b>target distribution, confussion matrix, scores and feature importance</b></font>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_42af0592_ac99_11ea_a522_985fd3cf311a" style='display:inline'><caption>target train</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >target_multi_label</th>        <th class="col_heading level0 col2" >proc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42af0592_ac99_11ea_a522_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow0_col1" class="data row0 col1" >14360</td>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow0_col2" class="data row0 col2" >39.740</td>
#             </tr>
#             <tr>
#                         <th id="T_42af0592_ac99_11ea_a522_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow1_col1" class="data row1 col1" >9213</td>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow1_col2" class="data row1 col2" >25.490</td>
#             </tr>
#             <tr>
#                         <th id="T_42af0592_ac99_11ea_a522_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow2_col0" class="data row2 col0" >3</td>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow2_col1" class="data row2 col1" >8126</td>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow2_col2" class="data row2 col2" >22.490</td>
#             </tr>
#             <tr>
#                         <th id="T_42af0592_ac99_11ea_a522_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow3_col0" class="data row3 col0" >2</td>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow3_col1" class="data row3 col1" >3326</td>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow3_col2" class="data row3 col2" >9.200</td>
#             </tr>
#             <tr>
#                         <th id="T_42af0592_ac99_11ea_a522_985fd3cf311alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow4_col0" class="data row4 col0" >4</td>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow4_col1" class="data row4 col1" >1114</td>
#                         <td id="T_42af0592_ac99_11ea_a522_985fd3cf311arow4_col2" class="data row4 col2" >3.080</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42af537e_ac99_11ea_96cd_985fd3cf311a" style='display:inline'><caption>target test</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >target_multi_label</th>        <th class="col_heading level0 col2" >proc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42af537e_ac99_11ea_96cd_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow0_col1" class="data row0 col1" >7191</td>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow0_col2" class="data row0 col2" >40.400</td>
#             </tr>
#             <tr>
#                         <th id="T_42af537e_ac99_11ea_96cd_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow1_col1" class="data row1 col1" >4578</td>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow1_col2" class="data row1 col2" >25.720</td>
#             </tr>
#             <tr>
#                         <th id="T_42af537e_ac99_11ea_96cd_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow2_col0" class="data row2 col0" >3</td>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow2_col1" class="data row2 col1" >3956</td>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow2_col2" class="data row2 col2" >22.220</td>
#             </tr>
#             <tr>
#                         <th id="T_42af537e_ac99_11ea_96cd_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow3_col0" class="data row3 col0" >2</td>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow3_col1" class="data row3 col1" >1580</td>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow3_col2" class="data row3 col2" >8.880</td>
#             </tr>
#             <tr>
#                         <th id="T_42af537e_ac99_11ea_96cd_985fd3cf311alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow4_col0" class="data row4 col0" >4</td>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow4_col1" class="data row4 col1" >496</td>
#                         <td id="T_42af537e_ac99_11ea_96cd_985fd3cf311arow4_col2" class="data row4 col2" >2.790</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42afa15c_ac99_11ea_b9a3_985fd3cf311a" style='display:inline'><caption>thresholds</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42afa15c_ac99_11ea_b9a3_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42afa15c_ac99_11ea_b9a3_985fd3cf311arow0_col0" class="data row0 col0" >0.500</td>
#             </tr>
#             <tr>
#                         <th id="T_42afa15c_ac99_11ea_b9a3_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42afa15c_ac99_11ea_b9a3_985fd3cf311arow1_col0" class="data row1 col0" >0.500</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_42b08b1e_ac99_11ea_b050_985fd3cf311a" style='display:inline'><caption>Confusion matrix  TRAIN ,   Model:  rf</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >_sum_</th>        <th class="col_heading level0 col6" >_correctness_</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42b08b1e_ac99_11ea_b050_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow0_col0" class="data row0 col0" >11795</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow0_col1" class="data row0 col1" >1701</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow0_col2" class="data row0 col2" >3</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow0_col3" class="data row0 col3" >858</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow0_col4" class="data row0 col4" >3</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow0_col5" class="data row0 col5" >14360</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow0_col6" class="data row0 col6" >82</td>
#             </tr>
#             <tr>
#                         <th id="T_42b08b1e_ac99_11ea_b050_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow1_col0" class="data row1 col0" >5218</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow1_col1" class="data row1 col1" >3380</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow1_col2" class="data row1 col2" >6</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow1_col3" class="data row1 col3" >609</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow1_col4" class="data row1 col4" >0</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow1_col5" class="data row1 col5" >9213</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow1_col6" class="data row1 col6" >36</td>
#             </tr>
#             <tr>
#                         <th id="T_42b08b1e_ac99_11ea_b050_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow2_col0" class="data row2 col0" >1327</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow2_col1" class="data row2 col1" >690</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow2_col2" class="data row2 col2" >368</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow2_col3" class="data row2 col3" >903</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow2_col4" class="data row2 col4" >38</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow2_col5" class="data row2 col5" >3326</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow2_col6" class="data row2 col6" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_42b08b1e_ac99_11ea_b050_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow3_col0" class="data row3 col0" >4347</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow3_col1" class="data row3 col1" >1462</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow3_col2" class="data row3 col2" >72</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow3_col3" class="data row3 col3" >2244</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow3_col4" class="data row3 col4" >1</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow3_col5" class="data row3 col5" >8126</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow3_col6" class="data row3 col6" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_42b08b1e_ac99_11ea_b050_985fd3cf311alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow4_col0" class="data row4 col0" >249</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow4_col1" class="data row4 col1" >335</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow4_col2" class="data row4 col2" >41</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow4_col3" class="data row4 col3" >90</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow4_col4" class="data row4 col4" >399</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow4_col5" class="data row4 col5" >1114</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow4_col6" class="data row4 col6" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_42b08b1e_ac99_11ea_b050_985fd3cf311alevel0_row5" class="row_heading level0 row5" >_sum_</th>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow5_col0" class="data row5 col0" >22936</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow5_col1" class="data row5 col1" >7568</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow5_col2" class="data row5 col2" >490</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow5_col3" class="data row5 col3" >4704</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow5_col4" class="data row5 col4" >441</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow5_col5" class="data row5 col5" >0</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow5_col6" class="data row5 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_42b08b1e_ac99_11ea_b050_985fd3cf311alevel0_row6" class="row_heading level0 row6" >_correctness_</th>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow6_col0" class="data row6 col0" >51</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow6_col1" class="data row6 col1" >44</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow6_col2" class="data row6 col2" >75</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow6_col3" class="data row6 col3" >47</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow6_col4" class="data row6 col4" >90</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow6_col5" class="data row6 col5" >0</td>
#                         <td id="T_42b08b1e_ac99_11ea_b050_985fd3cf311arow6_col6" class="data row6 col6" >0</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311a" style='display:inline'><caption>Confusion matrix  TEST,    Model:  rf</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >_sum_</th>        <th class="col_heading level0 col6" >_correctness_</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow0_col0" class="data row0 col0" >5852</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow0_col1" class="data row0 col1" >873</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow0_col3" class="data row0 col3" >465</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow0_col5" class="data row0 col5" >7191</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow0_col6" class="data row0 col6" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow1_col0" class="data row1 col0" >2640</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow1_col1" class="data row1 col1" >1636</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow1_col2" class="data row1 col2" >4</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow1_col3" class="data row1 col3" >295</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow1_col4" class="data row1 col4" >3</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow1_col5" class="data row1 col5" >4578</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow1_col6" class="data row1 col6" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow2_col0" class="data row2 col0" >646</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow2_col1" class="data row2 col1" >335</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow2_col2" class="data row2 col2" >162</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow2_col3" class="data row2 col3" >416</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow2_col4" class="data row2 col4" >21</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow2_col5" class="data row2 col5" >1580</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow2_col6" class="data row2 col6" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow3_col0" class="data row3 col0" >2112</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow3_col1" class="data row3 col1" >722</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow3_col2" class="data row3 col2" >56</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow3_col3" class="data row3 col3" >1063</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow3_col4" class="data row3 col4" >3</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow3_col5" class="data row3 col5" >3956</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow3_col6" class="data row3 col6" >26</td>
#             </tr>
#             <tr>
#                         <th id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow4_col0" class="data row4 col0" >100</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow4_col1" class="data row4 col1" >162</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow4_col2" class="data row4 col2" >31</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow4_col3" class="data row4 col3" >40</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow4_col4" class="data row4 col4" >163</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow4_col5" class="data row4 col5" >496</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow4_col6" class="data row4 col6" >32</td>
#             </tr>
#             <tr>
#                         <th id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311alevel0_row5" class="row_heading level0 row5" >_sum_</th>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow5_col0" class="data row5 col0" >11350</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow5_col1" class="data row5 col1" >3728</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow5_col2" class="data row5 col2" >254</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow5_col3" class="data row5 col3" >2279</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow5_col4" class="data row5 col4" >190</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow5_col5" class="data row5 col5" >0</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow5_col6" class="data row5 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311alevel0_row6" class="row_heading level0 row6" >_correctness_</th>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow6_col0" class="data row6 col0" >51</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow6_col1" class="data row6 col1" >43</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow6_col2" class="data row6 col2" >63</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow6_col3" class="data row6 col3" >46</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow6_col4" class="data row6 col4" >85</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow6_col5" class="data row6 col5" >0</td>
#                         <td id="T_42b237a4_ac99_11ea_bbf1_985fd3cf311arow6_col6" class="data row6 col6" >0</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_42b39670_ac99_11ea_bc64_985fd3cf311a" style='display:inline'><caption>score: accuracy</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42b39670_ac99_11ea_bc64_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42b39670_ac99_11ea_bc64_985fd3cf311arow0_col0" class="data row0 col0" >rf</td>
#                         <td id="T_42b39670_ac99_11ea_bc64_985fd3cf311arow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_42b39670_ac99_11ea_bc64_985fd3cf311arow0_col2" class="data row0 col2" >0.499</td>
#             </tr>
#             <tr>
#                         <th id="T_42b39670_ac99_11ea_bc64_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42b39670_ac99_11ea_bc64_985fd3cf311arow1_col0" class="data row1 col0" >rf</td>
#                         <td id="T_42b39670_ac99_11ea_bc64_985fd3cf311arow1_col1" class="data row1 col1" >train</td>
#                         <td id="T_42b39670_ac99_11ea_bc64_985fd3cf311arow1_col2" class="data row1 col2" >0.503</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42b3e438_ac99_11ea_bbd5_985fd3cf311a" style='display:inline'><caption>score: balanced_accuracy</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42b3e438_ac99_11ea_bbd5_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42b3e438_ac99_11ea_bbd5_985fd3cf311arow0_col0" class="data row0 col0" >rf</td>
#                         <td id="T_42b3e438_ac99_11ea_bbd5_985fd3cf311arow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_42b3e438_ac99_11ea_bbd5_985fd3cf311arow0_col2" class="data row0 col2" >0.374</td>
#             </tr>
#             <tr>
#                         <th id="T_42b3e438_ac99_11ea_bbd5_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42b3e438_ac99_11ea_bbd5_985fd3cf311arow1_col0" class="data row1 col0" >rf</td>
#                         <td id="T_42b3e438_ac99_11ea_bbd5_985fd3cf311arow1_col1" class="data row1 col1" >train</td>
#                         <td id="T_42b3e438_ac99_11ea_bbd5_985fd3cf311arow1_col2" class="data row1 col2" >0.387</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42b40b76_ac99_11ea_ae4e_985fd3cf311a" style='display:inline'><caption>score: recall</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42b40b76_ac99_11ea_ae4e_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42b40b76_ac99_11ea_ae4e_985fd3cf311arow0_col0" class="data row0 col0" >rf</td>
#                         <td id="T_42b40b76_ac99_11ea_ae4e_985fd3cf311arow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_42b40b76_ac99_11ea_ae4e_985fd3cf311arow0_col2" class="data row0 col2" >0.499</td>
#             </tr>
#             <tr>
#                         <th id="T_42b40b76_ac99_11ea_ae4e_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42b40b76_ac99_11ea_ae4e_985fd3cf311arow1_col0" class="data row1 col0" >rf</td>
#                         <td id="T_42b40b76_ac99_11ea_ae4e_985fd3cf311arow1_col1" class="data row1 col1" >train</td>
#                         <td id="T_42b40b76_ac99_11ea_ae4e_985fd3cf311arow1_col2" class="data row1 col2" >0.503</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42b43234_ac99_11ea_9bd9_985fd3cf311a" style='display:inline'><caption>score: precision</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42b43234_ac99_11ea_9bd9_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42b43234_ac99_11ea_9bd9_985fd3cf311arow0_col0" class="data row0 col0" >rf</td>
#                         <td id="T_42b43234_ac99_11ea_9bd9_985fd3cf311arow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_42b43234_ac99_11ea_9bd9_985fd3cf311arow0_col2" class="data row0 col2" >0.505</td>
#             </tr>
#             <tr>
#                         <th id="T_42b43234_ac99_11ea_9bd9_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42b43234_ac99_11ea_9bd9_985fd3cf311arow1_col0" class="data row1 col0" >rf</td>
#                         <td id="T_42b43234_ac99_11ea_9bd9_985fd3cf311arow1_col1" class="data row1 col1" >train</td>
#                         <td id="T_42b43234_ac99_11ea_9bd9_985fd3cf311arow1_col2" class="data row1 col2" >0.522</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42b4807e_ac99_11ea_9fe2_985fd3cf311a" style='display:inline'><caption>score: f1</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42b4807e_ac99_11ea_9fe2_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42b4807e_ac99_11ea_9fe2_985fd3cf311arow0_col0" class="data row0 col0" >rf</td>
#                         <td id="T_42b4807e_ac99_11ea_9fe2_985fd3cf311arow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_42b4807e_ac99_11ea_9fe2_985fd3cf311arow0_col2" class="data row0 col2" >0.461</td>
#             </tr>
#             <tr>
#                         <th id="T_42b4807e_ac99_11ea_9fe2_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42b4807e_ac99_11ea_9fe2_985fd3cf311arow1_col0" class="data row1 col0" >rf</td>
#                         <td id="T_42b4807e_ac99_11ea_9fe2_985fd3cf311arow1_col1" class="data row1 col1" >train</td>
#                         <td id="T_42b4807e_ac99_11ea_9fe2_985fd3cf311arow1_col2" class="data row1 col2" >0.466</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_42b590c6_ac99_11ea_af74_985fd3cf311a" style='display:inline'><caption>Feature Importance e-net</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >elastic_net</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42b590c6_ac99_11ea_af74_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42b590c6_ac99_11ea_af74_985fd3cf311arow0_col0" class="data row0 col0" >not calculated</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42b5b7be_ac99_11ea_9112_985fd3cf311a" style='display:inline'><caption>Feature Importance RF</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Importance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42b5b7be_ac99_11ea_9112_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow0_col0" class="data row0 col0" >z</td>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow0_col1" class="data row0 col1" >0.270</td>
#             </tr>
#             <tr>
#                         <th id="T_42b5b7be_ac99_11ea_9112_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow1_col0" class="data row1 col0" >x</td>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow1_col1" class="data row1 col1" >0.260</td>
#             </tr>
#             <tr>
#                         <th id="T_42b5b7be_ac99_11ea_9112_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow2_col0" class="data row2 col0" >y</td>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow2_col1" class="data row2 col1" >0.210</td>
#             </tr>
#             <tr>
#                         <th id="T_42b5b7be_ac99_11ea_9112_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow3_col0" class="data row3 col0" >price</td>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow3_col1" class="data row3 col1" >0.140</td>
#             </tr>
#             <tr>
#                         <th id="T_42b5b7be_ac99_11ea_9112_985fd3cf311alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow4_col0" class="data row4 col0" >NOISE_uniform</td>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow4_col1" class="data row4 col1" >0.050</td>
#             </tr>
#             <tr>
#                         <th id="T_42b5b7be_ac99_11ea_9112_985fd3cf311alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow5_col0" class="data row5 col0" >NOISE_normal</td>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow5_col1" class="data row5 col1" >0.040</td>
#             </tr>
#             <tr>
#                         <th id="T_42b5b7be_ac99_11ea_9112_985fd3cf311alevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow6_col0" class="data row6 col0" >color</td>
#                         <td id="T_42b5b7be_ac99_11ea_9112_985fd3cf311arow6_col1" class="data row6 col1" >0.030</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42b60600_ac99_11ea_b788_985fd3cf311a" style='display:inline'><caption>Feature Permutation Importance RF</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Importance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42b60600_ac99_11ea_b788_985fd3cf311alevel0_row0" class="row_heading level0 row0" >7</th>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow0_col0" class="data row0 col0" >z</td>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow0_col1" class="data row0 col1" >1.810</td>
#             </tr>
#             <tr>
#                         <th id="T_42b60600_ac99_11ea_b788_985fd3cf311alevel0_row1" class="row_heading level0 row1" >8</th>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow1_col0" class="data row1 col0" >x</td>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow1_col1" class="data row1 col1" >0.710</td>
#             </tr>
#             <tr>
#                         <th id="T_42b60600_ac99_11ea_b788_985fd3cf311alevel0_row2" class="row_heading level0 row2" >9</th>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow2_col0" class="data row2 col0" >y</td>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow2_col1" class="data row2 col1" >0.560</td>
#             </tr>
#             <tr>
#                         <th id="T_42b60600_ac99_11ea_b788_985fd3cf311alevel0_row3" class="row_heading level0 row3" >10</th>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow3_col0" class="data row3 col0" >price</td>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow3_col1" class="data row3 col1" >0.180</td>
#             </tr>
#             <tr>
#                         <th id="T_42b60600_ac99_11ea_b788_985fd3cf311alevel0_row4" class="row_heading level0 row4" >11</th>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow4_col0" class="data row4 col0" >color</td>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow4_col1" class="data row4 col1" >0.010</td>
#             </tr>
#             <tr>
#                         <th id="T_42b60600_ac99_11ea_b788_985fd3cf311alevel0_row5" class="row_heading level0 row5" >12</th>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow5_col0" class="data row5 col0" >NOISE_uniform</td>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow5_col1" class="data row5 col1" >0.010</td>
#             </tr>
#             <tr>
#                         <th id="T_42b60600_ac99_11ea_b788_985fd3cf311alevel0_row6" class="row_heading level0 row6" >13</th>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow6_col0" class="data row6 col0" >NOISE_normal</td>
#                         <td id="T_42b60600_ac99_11ea_b788_985fd3cf311arow6_col1" class="data row6 col1" >-0.010</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_42b67aa8_ac99_11ea_9f48_985fd3cf311a" style='display:inline'><caption>Feature Importance CATBOOST</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Importance</th>    </tr></thead><tbody>
#         </tbody></table>
# [None,
#  None,
#  None,
#  None,
#  None,
#  'recall = TP / TP + FN;   precision = TP / (TP + FP);    f1 = ( 2*TP ) / (2*TP + FP + FN );   balanced_accuracy = (TP/(TP+FN) + TN/(TN+FP)) / 2 ']
# <font size = "3"><b>density plots</b></font>
# <ggplot: (168077614263)>
# <ggplot: (168081200311)>
# <font size = "3"><b>density plot for Feature Importatnce Permutation</b></font>
# <ggplot: (168074789794)>
# <ggplot: (-9223371868777161030)>
# <font size = "3"><b>scores by cross validation</b></font>
# <ggplot: (168074687478)>
# <ggplot: (-9223371868777557167)>
# <font size = "3"><b>scores by holdout</b></font>
# <ggplot: (168098414989)>
# <ggplot: (-9223371868784024758)>
# <font size = "3"><b>scores by by_var</b></font>
# <ggplot: (-9223371868766448689)>
# <ggplot: (-9223371868786122331)>
# <font size = "3"><b>pr and roc curve</b></font>
# rf
# <ggplot: (168078412029)>
# <ggplot: (168074907859)>
#             average_precision
# rf - 0 - 1              0.442
#             roc_auc
# rf - 0 - 1    0.699
# <font size = "3"><b>pr and roc curve for Feature Importatnce Permutation</b></font>
# rf
# price
# x
# y
# z
# color
# <ggplot: (-9223371868776131619)>
# <ggplot: (168070029709)>
#                average_precision
# price - 0 - 1              0.478
# color - 0 - 1              0.474
# rf - 0 - 1                 0.442
# y - 0 - 1                  0.415
# z - 0 - 1                  0.410
# x - 0 - 1                  0.377
#                roc_auc
# color - 0 - 1    0.723
# price - 0 - 1    0.718
# rf - 0 - 1       0.699
# y - 0 - 1        0.686
# z - 0 - 1        0.681
# x - 0 - 1        0.653

# %% [markdown]
# # Łączenie modeli

# %% [markdown]
# ## Agregacja wynikow
#
# Zakładam że mam dwa różne modele na rozłączych zbiorach danych i chce uzyskać ja nich zagregowaną macierz pomysłek i scory

# %% [markdown]
# ### Model 1

# %%
# zmienne
y_var = ['target_multi_label']        # zmianna objasniana
x_var_num = ['y', 'z']                # zmienne objasniajace numeryczne
x_var_cat = ['color','clarity'] # zmienne objasniajace kategoryczne
x_var = x_var_num + x_var_cat         # wszystkie zmienna objasniajace

# zbior danych dla pierwsego modelu
data_model_1 = data.iloc[1:10000,:]

# podzial na zbioru 'data' na train i test
x_train, x_test, y_train, y_test = skl.model_selection.train_test_split(data_model_1[x_var], data_model_1[y_var], test_size=0.33)

# reset indexow na zbiorach
x_train = x_train.reset_index(drop=True)
x_test  = x_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test  = y_test.reset_index(drop=True)

# umieszczenie w jednym zbiorze zmiennych objasniajacych i zmiennej objasnianej
train_set = pd.concat([x_train, y_train], axis = 1)
test_set  = pd.concat([x_test, y_test], axis = 1)

# zamiana zmiennej objasnianej na typ 'str'
train_set[y_var] = train_set[y_var].astype(str)
test_set[y_var]  = test_set[y_var].astype(str)

# %%
# Parametry symulacji do UCZENIA MODELI
simulation_name        = 'symulacja_1_do_agreg' # unikalna nazwa symulacji
simulation_description = 'symulacja pierwsza do agregacji' # opis symulacji
models_list            = {'rf':models_base['rf'], 'cat':models_base['cat']} # slownik modeli do nauki wybranych z listy 'model_base'
cv_n                   = None     # walidacja krzyzowa: ilosc k-foldow na walidacji krzyzowej (None jezeli nie chcemy walidacji krzyzowej)
hold_n                 = None     # walidacja holdout: ilosc samplow na holdout (None jezeli nie chcemy walidacji holdout)
hold_train_sample_size = 0.1   # walidacja holdout: wielkosc losowanego zbioru train na holdout
hold_test_sample_size  = 0.1   # walidacja holdout: wielkosc losowanego zbioru test na holdout
fip_n                  = None     # walidacja feature importatnce permutation:  ilosc samplow (None jezeli nie chcemy. Jezeli chcemy, zalecana wartosc to 1)
model_fip              = RandomForestClassifier(n_estimators=20, max_depth=7) # walidacja feature importatnce permutation: okreslenie modelu
by_var                 = None # walidacja segmentacyjna: zmienna po ktore wykonac segmentacje by_var (None jezeli nie chcemy)
pos_label              = '1'   # ktory label zmiennej objasnianej jest traktowany jako 'positive'
balancing_method       = None  # metoda balansowania (dostepne: ''over', 'under', 'None')
calibration_method     = None # metoda kalibracji prawdopodobienstwa (dostepne : 'isotonic', 'None')
cat_encoding_method    = 'target' # metoda enkodowania zmiennych kategorycznych (dostepne: 'target', 'None')

# parematry dla PERFORMANCE
threshold              = {'0':0.5, '1':0.5} # thresholdy dla kazdej kategorii (jezeli damy 'None' przypisywanie odbywa sie poprzez max(pd))


# inicjalizacja nowego obiektu do symulacji (na tym obiekcie bedziemy wykonywac kolejne symulacje, więc kolejne inicjalizacje nie sa potrzebne)
c1 = classification_model()

# UCZENIE MODELI (obliczane tylko prawdopodobienstwa)
c1.simulation(  train_set = train_set, test_set = test_set, y_var = y_var, x_var_num = x_var_num, x_var_cat = x_var_cat, by_var=by_var
              , balancing_method=balancing_method
              , cv_n=cv_n, fip_n=fip_n, hold_n = hold_n, hold_train_sample_size = hold_train_sample_size, hold_test_sample_size = hold_test_sample_size
              , data_check=True, models_list=models_list, correlation = True, model_fip = RandomForestClassifier(n_estimators=30, max_depth=7)
              , simulation_name = simulation_name, description = simulation_description)

# PERFORMANCE (na uzyskane w poprzednim kroku prawdopodobienstwa nadkladamy thresholdy i liczymy scory confusion matrix itp.)
c1.performance(simulation_name=simulation_name, threshold=threshold, priori =  None)

# zapisanie wynikow na dysk
c1.save_results(path = r'C:\Users\memy\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\results\symulacja_1', override = True)
# Out:
# (6699, 5)
# (3300, 5)
# (6699, 5)
# (3300, 5)
# full 0
# full 1
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# feature_importance
# THRESHOLD
# {'0': 0.5, '1': 0.5}
# ('symulacja_1_do_agreg', 'cat', 'test', 'full', 0, '_', 0)
# ('symulacja_1_do_agreg', 'cat', 'test', 'full', 0, '_', 1)
# ('symulacja_1_do_agreg', 'cat', 'train', 'full', 0, '_', 0)
# ('symulacja_1_do_agreg', 'cat', 'train', 'full', 0, '_', 1)
# ('symulacja_1_do_agreg', 'rf', 'test', 'full', 0, '_', 0)
# ('symulacja_1_do_agreg', 'rf', 'test', 'full', 0, '_', 1)
# ('symulacja_1_do_agreg', 'rf', 'train', 'full', 0, '_', 0)
# ('symulacja_1_do_agreg', 'rf', 'train', 'full', 0, '_', 1)

# %% [markdown]
# ### Model 2

# %%
# zmienne
y_var = ['target_multi_label']        # zmianna objasniana
x_var_num = ['price', 'x']  # zmienne objasniajace numeryczne
x_var_cat = ['color','clarity','cut'] # zmienne objasniajace kategoryczne
x_var = x_var_num + x_var_cat         # wszystkie zmienna objasniajace

# zbior danych dla drugiego modelu
data_model_2 = data.iloc[10000:20000,:]

# podzial na zbioru 'data' na train i test
x_train, x_test, y_train, y_test = skl.model_selection.train_test_split(data_model_2[x_var], data_model_2[y_var], test_size=0.33)

# reset indexow na zbiorach
x_train = x_train.reset_index(drop=True)
x_test  = x_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test  = y_test.reset_index(drop=True)

# umieszczenie w jednym zbiorze zmiennych objasniajacych i zmiennej objasnianej
train_set = pd.concat([x_train, y_train], axis = 1)
test_set  = pd.concat([x_test, y_test], axis = 1)

# zamiana zmiennej objasnianej na typ 'str'
train_set[y_var] = train_set[y_var].astype(str)
test_set[y_var]  = test_set[y_var].astype(str)

# %%
# Parametry symulacji do UCZENIA MODELI
simulation_name        = 'symulacja_2_do_agreg' # unikalna nazwa symulacji
simulation_description = 'symulacja druga do agregacji' # opis symulacji
models_list            = {'rf':models_base['rf'], 'cat':models_base['cat']} # slownik modeli do nauki wybranych z listy 'model_base'
cv_n                   = None     # walidacja krzyzowa: ilosc k-foldow na walidacji krzyzowej (None jezeli nie chcemy walidacji krzyzowej)
hold_n                 = None     # walidacja holdout: ilosc samplow na holdout (None jezeli nie chcemy walidacji holdout)
hold_train_sample_size = 0.1   # walidacja holdout: wielkosc losowanego zbioru train na holdout
hold_test_sample_size  = 0.1   # walidacja holdout: wielkosc losowanego zbioru test na holdout
fip_n                  = None     # walidacja feature importatnce permutation:  ilosc samplow (None jezeli nie chcemy. Jezeli chcemy, zalecana wartosc to 1)
model_fip              = RandomForestClassifier(n_estimators=20, max_depth=7) # walidacja feature importatnce permutation: okreslenie modelu
by_var                 = None # walidacja segmentacyjna: zmienna po ktore wykonac segmentacje by_var (None jezeli nie chcemy)
pos_label              = '1'   # ktory label zmiennej objasnianej jest traktowany jako 'positive'
balancing_method       = None  # metoda balansowania (dostepne: ''over', 'under', 'None')
calibration_method     = None # metoda kalibracji prawdopodobienstwa (dostepne : 'isotonic', 'None')
cat_encoding_method    = 'target' # metoda enkodowania zmiennych kategorycznych (dostepne: 'target', 'None')

# parematry dla PERFORMANCE
threshold              = {'0':0.5, '1':0.5} # thresholdy dla kazdej kategorii (jezeli damy 'None' przypisywanie odbywa sie poprzez max(pd))


# inicjalizacja nowego obiektu do symulacji : NIE JEST WYKONYWANA. PRACJEMY DALEJ NA OBIEKCIE W POPRZEDNIEJ SYMULACJI


# UCZENIE MODELI (obliczane tylko prawdopodobienstwa)
c1.simulation(  train_set = train_set, test_set = test_set, y_var = y_var, x_var_num = x_var_num, x_var_cat = x_var_cat, by_var=by_var
              , balancing_method=balancing_method
              , cv_n=cv_n, fip_n=fip_n, hold_n = hold_n, hold_train_sample_size = hold_train_sample_size, hold_test_sample_size = hold_test_sample_size
              , data_check=True, models_list=models_list, correlation = True, model_fip = RandomForestClassifier(n_estimators=30, max_depth=7)
              , simulation_name = simulation_name, description = simulation_description)

# PERFORMANCE (na uzyskane w poprzednim kroku prawdopodobienstwa nadkladamy thresholdy i liczymy scory confusion matrix itp.)
c1.performance(simulation_name=simulation_name, threshold=threshold, priori =  None)

# zapisanie wynikow na dysk
c1.save_results(path = r'C:\Users\memy\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\results\symulacja_1', override = True)
# Out:
# (6700, 6)
# (3300, 6)
# (6700, 6)
# (3300, 6)
# full 0
# full 1
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# feature_importance
# THRESHOLD
# {'0': 0.5, '1': 0.5}
# ('symulacja_2_do_agreg', 'cat', 'test', 'full', 0, '_', 0)
# ('symulacja_2_do_agreg', 'cat', 'test', 'full', 0, '_', 1)
# ('symulacja_2_do_agreg', 'cat', 'train', 'full', 0, '_', 0)
# ('symulacja_2_do_agreg', 'cat', 'train', 'full', 0, '_', 1)
# ('symulacja_2_do_agreg', 'rf', 'test', 'full', 0, '_', 0)
# ('symulacja_2_do_agreg', 'rf', 'test', 'full', 0, '_', 1)
# ('symulacja_2_do_agreg', 'rf', 'train', 'full', 0, '_', 0)
# ('symulacja_2_do_agreg', 'rf', 'train', 'full', 0, '_', 1)

# %% [markdown]
# ### Połączone wyniki modeli 1 i 2

# %%
c1.scores_cf_agg_full(simulation_params = [['symulacja_1_do_agreg','cat'], ['symulacja_2_do_agreg','cat']], if_automatic=0, pos_label = pos_label)

# nazwa nowgo polaczonego performance
simulation_new_name = '_' + 'symulacja_1_do_agreg' + '_' +  'symulacja_2_do_agreg'

h('target distribution, confussion matrix, scores and feature importance')
c1.fast_conf_matrix_scores(simulation_name = simulation_new_name)
# Out:
# <font size = "3"><b>target distribution, confussion matrix, scores and feature importance</b></font>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_6645633a_acb4_11ea_a2d1_985fd3cf311a" style='display:inline'><caption>target train</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >target_multi_label</th>        <th class="col_heading level0 col2" >proc</th>    </tr></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_6646275a_acb4_11ea_830b_985fd3cf311a" style='display:inline'><caption>target test</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >target_multi_label</th>        <th class="col_heading level0 col2" >proc</th>    </tr></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_66464cf0_acb4_11ea_a6ce_985fd3cf311a" style='display:inline'><caption>thresholds</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_66464cf0_acb4_11ea_a6ce_985fd3cf311alevel0_row0" class="row_heading level0 row0" >no_threshold</th>
#                         <td id="T_66464cf0_acb4_11ea_a6ce_985fd3cf311arow0_col0" class="data row0 col0" >NaN</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_664736ba_acb4_11ea_b5a7_985fd3cf311a" style='display:inline'><caption>Confusion matrix  TRAIN ,   Model:  _cat_cat</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >_sum_</th>        <th class="col_heading level0 col6" >_correctness_</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_664736ba_acb4_11ea_b5a7_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow0_col0" class="data row0 col0" >3730</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow0_col1" class="data row0 col1" >353</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow0_col2" class="data row0 col2" >12</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow0_col3" class="data row0 col3" >260</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow0_col5" class="data row0 col5" >4355</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow0_col6" class="data row0 col6" >85</td>
#             </tr>
#             <tr>
#                         <th id="T_664736ba_acb4_11ea_b5a7_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow1_col0" class="data row1 col0" >609</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow1_col1" class="data row1 col1" >2711</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow1_col2" class="data row1 col2" >43</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow1_col3" class="data row1 col3" >336</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow1_col4" class="data row1 col4" >1</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow1_col5" class="data row1 col5" >3700</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow1_col6" class="data row1 col6" >73</td>
#             </tr>
#             <tr>
#                         <th id="T_664736ba_acb4_11ea_b5a7_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow2_col0" class="data row2 col0" >192</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow2_col1" class="data row2 col1" >205</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow2_col2" class="data row2 col2" >935</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow2_col3" class="data row2 col3" >150</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow2_col4" class="data row2 col4" >30</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow2_col5" class="data row2 col5" >1512</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow2_col6" class="data row2 col6" >61</td>
#             </tr>
#             <tr>
#                         <th id="T_664736ba_acb4_11ea_b5a7_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow3_col0" class="data row3 col0" >623</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow3_col1" class="data row3 col1" >441</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow3_col2" class="data row3 col2" >132</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow3_col3" class="data row3 col3" >2071</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow3_col4" class="data row3 col4" >2</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow3_col5" class="data row3 col5" >3269</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow3_col6" class="data row3 col6" >63</td>
#             </tr>
#             <tr>
#                         <th id="T_664736ba_acb4_11ea_b5a7_985fd3cf311alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow4_col0" class="data row4 col0" >23</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow4_col1" class="data row4 col1" >35</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow4_col2" class="data row4 col2" >58</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow4_col3" class="data row4 col3" >15</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow4_col4" class="data row4 col4" >432</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow4_col5" class="data row4 col5" >563</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow4_col6" class="data row4 col6" >76</td>
#             </tr>
#             <tr>
#                         <th id="T_664736ba_acb4_11ea_b5a7_985fd3cf311alevel0_row5" class="row_heading level0 row5" >_sum_</th>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow5_col0" class="data row5 col0" >5177</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow5_col1" class="data row5 col1" >3745</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow5_col2" class="data row5 col2" >1180</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow5_col3" class="data row5 col3" >2832</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow5_col4" class="data row5 col4" >465</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow5_col5" class="data row5 col5" >0</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow5_col6" class="data row5 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_664736ba_acb4_11ea_b5a7_985fd3cf311alevel0_row6" class="row_heading level0 row6" >_correctness_</th>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow6_col0" class="data row6 col0" >72</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow6_col1" class="data row6 col1" >72</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow6_col2" class="data row6 col2" >79</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow6_col3" class="data row6 col3" >73</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow6_col4" class="data row6 col4" >92</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow6_col5" class="data row6 col5" >0</td>
#                         <td id="T_664736ba_acb4_11ea_b5a7_985fd3cf311arow6_col6" class="data row6 col6" >0</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_6648bc68_acb4_11ea_9926_985fd3cf311a" style='display:inline'><caption>Confusion matrix  TEST,    Model:  _cat_cat</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >_sum_</th>        <th class="col_heading level0 col6" >_correctness_</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6648bc68_acb4_11ea_9926_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow0_col0" class="data row0 col0" >1797</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow0_col1" class="data row0 col1" >183</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow0_col2" class="data row0 col2" >5</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow0_col3" class="data row0 col3" >125</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow0_col5" class="data row0 col5" >2110</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow0_col6" class="data row0 col6" >85</td>
#             </tr>
#             <tr>
#                         <th id="T_6648bc68_acb4_11ea_9926_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow1_col0" class="data row1 col0" >312</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow1_col1" class="data row1 col1" >1293</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow1_col2" class="data row1 col2" >27</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow1_col3" class="data row1 col3" >173</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow1_col4" class="data row1 col4" >0</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow1_col5" class="data row1 col5" >1805</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow1_col6" class="data row1 col6" >71</td>
#             </tr>
#             <tr>
#                         <th id="T_6648bc68_acb4_11ea_9926_985fd3cf311alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow2_col0" class="data row2 col0" >108</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow2_col1" class="data row2 col1" >87</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow2_col2" class="data row2 col2" >485</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow2_col3" class="data row2 col3" >83</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow2_col4" class="data row2 col4" >7</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow2_col5" class="data row2 col5" >770</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow2_col6" class="data row2 col6" >62</td>
#             </tr>
#             <tr>
#                         <th id="T_6648bc68_acb4_11ea_9926_985fd3cf311alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow3_col0" class="data row3 col0" >337</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow3_col1" class="data row3 col1" >214</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow3_col2" class="data row3 col2" >73</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow3_col3" class="data row3 col3" >1043</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow3_col4" class="data row3 col4" >0</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow3_col5" class="data row3 col5" >1667</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow3_col6" class="data row3 col6" >62</td>
#             </tr>
#             <tr>
#                         <th id="T_6648bc68_acb4_11ea_9926_985fd3cf311alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow4_col0" class="data row4 col0" >10</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow4_col1" class="data row4 col1" >12</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow4_col2" class="data row4 col2" >43</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow4_col3" class="data row4 col3" >8</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow4_col4" class="data row4 col4" >175</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow4_col5" class="data row4 col5" >248</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow4_col6" class="data row4 col6" >70</td>
#             </tr>
#             <tr>
#                         <th id="T_6648bc68_acb4_11ea_9926_985fd3cf311alevel0_row5" class="row_heading level0 row5" >_sum_</th>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow5_col0" class="data row5 col0" >2564</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow5_col1" class="data row5 col1" >1789</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow5_col2" class="data row5 col2" >633</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow5_col3" class="data row5 col3" >1432</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow5_col4" class="data row5 col4" >182</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow5_col5" class="data row5 col5" >0</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow5_col6" class="data row5 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6648bc68_acb4_11ea_9926_985fd3cf311alevel0_row6" class="row_heading level0 row6" >_correctness_</th>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow6_col0" class="data row6 col0" >70</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow6_col1" class="data row6 col1" >72</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow6_col2" class="data row6 col2" >76</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow6_col3" class="data row6 col3" >72</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow6_col4" class="data row6 col4" >96</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow6_col5" class="data row6 col5" >0</td>
#                         <td id="T_6648bc68_acb4_11ea_9926_985fd3cf311arow6_col6" class="data row6 col6" >0</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_664a41e4_acb4_11ea_ab64_985fd3cf311a" style='display:inline'><caption>score: accuracy</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_664a41e4_acb4_11ea_ab64_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_664a41e4_acb4_11ea_ab64_985fd3cf311arow0_col0" class="data row0 col0" >_cat_cat</td>
#                         <td id="T_664a41e4_acb4_11ea_ab64_985fd3cf311arow0_col1" class="data row0 col1" >train</td>
#                         <td id="T_664a41e4_acb4_11ea_ab64_985fd3cf311arow0_col2" class="data row0 col2" >0.737</td>
#             </tr>
#             <tr>
#                         <th id="T_664a41e4_acb4_11ea_ab64_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_664a41e4_acb4_11ea_ab64_985fd3cf311arow1_col0" class="data row1 col0" >_cat_cat</td>
#                         <td id="T_664a41e4_acb4_11ea_ab64_985fd3cf311arow1_col1" class="data row1 col1" >test</td>
#                         <td id="T_664a41e4_acb4_11ea_ab64_985fd3cf311arow1_col2" class="data row1 col2" >0.726</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_664a8fdc_acb4_11ea_997c_985fd3cf311a" style='display:inline'><caption>score: balanced_accuracy</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_664a8fdc_acb4_11ea_997c_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_664a8fdc_acb4_11ea_997c_985fd3cf311arow0_col0" class="data row0 col0" >_cat_cat</td>
#                         <td id="T_664a8fdc_acb4_11ea_997c_985fd3cf311arow0_col1" class="data row0 col1" >train</td>
#                         <td id="T_664a8fdc_acb4_11ea_997c_985fd3cf311arow0_col2" class="data row0 col2" >0.722</td>
#             </tr>
#             <tr>
#                         <th id="T_664a8fdc_acb4_11ea_997c_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_664a8fdc_acb4_11ea_997c_985fd3cf311arow1_col0" class="data row1 col0" >_cat_cat</td>
#                         <td id="T_664a8fdc_acb4_11ea_997c_985fd3cf311arow1_col1" class="data row1 col1" >test</td>
#                         <td id="T_664a8fdc_acb4_11ea_997c_985fd3cf311arow1_col2" class="data row1 col2" >0.706</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_664addfa_acb4_11ea_85de_985fd3cf311a" style='display:inline'><caption>score: recall</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_664addfa_acb4_11ea_85de_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_664addfa_acb4_11ea_85de_985fd3cf311arow0_col0" class="data row0 col0" >_cat_cat</td>
#                         <td id="T_664addfa_acb4_11ea_85de_985fd3cf311arow0_col1" class="data row0 col1" >train</td>
#                         <td id="T_664addfa_acb4_11ea_85de_985fd3cf311arow0_col2" class="data row0 col2" >0.737</td>
#             </tr>
#             <tr>
#                         <th id="T_664addfa_acb4_11ea_85de_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_664addfa_acb4_11ea_85de_985fd3cf311arow1_col0" class="data row1 col0" >_cat_cat</td>
#                         <td id="T_664addfa_acb4_11ea_85de_985fd3cf311arow1_col1" class="data row1 col1" >test</td>
#                         <td id="T_664addfa_acb4_11ea_85de_985fd3cf311arow1_col2" class="data row1 col2" >0.726</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_664b2bca_acb4_11ea_a68e_985fd3cf311a" style='display:inline'><caption>score: precision</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_664b2bca_acb4_11ea_a68e_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_664b2bca_acb4_11ea_a68e_985fd3cf311arow0_col0" class="data row0 col0" >_cat_cat</td>
#                         <td id="T_664b2bca_acb4_11ea_a68e_985fd3cf311arow0_col1" class="data row0 col1" >train</td>
#                         <td id="T_664b2bca_acb4_11ea_a68e_985fd3cf311arow0_col2" class="data row0 col2" >0.741</td>
#             </tr>
#             <tr>
#                         <th id="T_664b2bca_acb4_11ea_a68e_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_664b2bca_acb4_11ea_a68e_985fd3cf311arow1_col0" class="data row1 col0" >_cat_cat</td>
#                         <td id="T_664b2bca_acb4_11ea_a68e_985fd3cf311arow1_col1" class="data row1 col1" >test</td>
#                         <td id="T_664b2bca_acb4_11ea_a68e_985fd3cf311arow1_col2" class="data row1 col2" >0.731</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_664b798c_acb4_11ea_902b_985fd3cf311a" style='display:inline'><caption>score: f1</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_name</th>        <th class="col_heading level0 col1" >set_type</th>        <th class="col_heading level0 col2" >score_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_664b798c_acb4_11ea_902b_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_664b798c_acb4_11ea_902b_985fd3cf311arow0_col0" class="data row0 col0" >_cat_cat</td>
#                         <td id="T_664b798c_acb4_11ea_902b_985fd3cf311arow0_col1" class="data row0 col1" >train</td>
#                         <td id="T_664b798c_acb4_11ea_902b_985fd3cf311arow0_col2" class="data row0 col2" >0.735</td>
#             </tr>
#             <tr>
#                         <th id="T_664b798c_acb4_11ea_902b_985fd3cf311alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_664b798c_acb4_11ea_902b_985fd3cf311arow1_col0" class="data row1 col0" >_cat_cat</td>
#                         <td id="T_664b798c_acb4_11ea_902b_985fd3cf311arow1_col1" class="data row1 col1" >test</td>
#                         <td id="T_664b798c_acb4_11ea_902b_985fd3cf311arow1_col2" class="data row1 col2" >0.724</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_664cd830_acb4_11ea_aa55_985fd3cf311a" style='display:inline'><caption>Feature Importance e-net</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >elastic_net</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_664cd830_acb4_11ea_aa55_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_664cd830_acb4_11ea_aa55_985fd3cf311arow0_col0" class="data row0 col0" >not calculated</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_664d2628_acb4_11ea_914c_985fd3cf311a" style='display:inline'><caption>Feature Importance RF</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Importance</th>    </tr></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_664d4d1a_acb4_11ea_83cb_985fd3cf311a" style='display:inline'><caption>Feature Permutation Importance RF</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Importance</th>    </tr></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_664d740a_acb4_11ea_9812_985fd3cf311a" style='display:inline'><caption>Feature Importance CATBOOST</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Importance</th>    </tr></thead><tbody>
#         </tbody></table>
# [None,
#  None,
#  None,
#  None,
#  None,
#  'recall = TP / TP + FN;   precision = TP / (TP + FP);    f1 = ( 2*TP ) / (2*TP + FP + FN );   balanced_accuracy = (TP/(TP+FN) + TN/(TN+FP)) / 2 ']

# %% [markdown]
# ## Usrednianie prawdopodobienstw
#
# Jezeli usredniam miedzy roznymi symulacjami to zakladam ze byly one zbudowane na zbiorach z tymi samymi obserwacjami ktore byly tak samo posortowane

# %% [markdown]
# ### Model 1

# %%
# zmienne
y_var = ['target_multi_label']        # zmianna objasniana
x_var_num = ['price', 'table']        # zmienne objasniajace numeryczne
x_var_cat = ['color','clarity','cut'] # zmienne objasniajace kategoryczne
x_var = x_var_num + x_var_cat         # wszystkie zmienna objasniajace

# podzial na zbioru 'data' na train i test
x_train, x_test, y_train, y_test = skl.model_selection.train_test_split(data[x_var], data[y_var], test_size=0.33)

# reset indexow na zbiorach
x_train = x_train.reset_index(drop=True)
x_test  = x_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test  = y_test.reset_index(drop=True)

# umieszczenie w jednym zbiorze zmiennych objasniajacych i zmiennej objasnianej
train_set = pd.concat([x_train, y_train], axis = 1)
test_set  = pd.concat([x_test, y_test], axis = 1)

# zamiana zmiennej objasnianej na typ 'str'
train_set[y_var] = train_set[y_var].astype(str)
test_set[y_var]  = test_set[y_var].astype(str)

# %%
# Parametry symulacji do UCZENIA MODELI
simulation_name        = 'symulacja_1_do_usredn' # unikalna nazwa symulacji
simulation_description = 'symulacja pierwsza do usredniania' # opis symulacji
models_list            = {'rf':models_base['rf'], 'ab':models_base['ab']} # slownik modeli do nauki wybranych z listy 'model_base'
cv_n                   = 4     # walidacja krzyzowa: ilosc k-foldow na walidacji krzyzowej (None jezeli nie chcemy walidacji krzyzowej)
hold_n                 = 4     # walidacja holdout: ilosc samplow na holdout (None jezeli nie chcemy walidacji holdout)
hold_train_sample_size = 0.1   # walidacja holdout: wielkosc losowanego zbioru train na holdout
hold_test_sample_size  = 0.1   # walidacja holdout: wielkosc losowanego zbioru test na holdout
fip_n                  = 1     # walidacja feature importatnce permutation:  ilosc samplow (None jezeli nie chcemy. Jezeli chcemy, zalecana wartosc to 1)
model_fip              = RandomForestClassifier(n_estimators=20, max_depth=7) # walidacja feature importatnce permutation: okreslenie modelu
by_var                 = 'cut' # walidacja segmentacyjna: zmienna po ktore wykonac segmentacje by_var (None jezeli nie chcemy)
pos_label              = '1'   # ktory label zmiennej objasnianej jest traktowany jako 'positive'
balancing_method       = None  # metoda balansowania (dostepne: ''over', 'under', 'None')
calibration_method     = None # metoda kalibracji prawdopodobienstwa (dostepne : 'isotonic', 'None')
cat_encoding_method    = 'target' # metoda enkodowania zmiennych kategorycznych (dostepne: 'target', 'None')

# parematry dla PERFORMANCE
threshold              = {'0':0.5, '1':0.5} # thresholdy dla kazdej kategorii (jezeli damy 'None' przypisywanie odbywa sie poprzez max(pd))


# inicjalizacja nowego obiektu do symulacji (na tym obiekcie bedziemy wykonywac kolejne symulacje, więc kolejne inicjalizacje nie sa potrzebne)
c1 = classification_model()


# UCZENIE MODELI (obliczane tylko prawdopodobienstwa)
c1.simulation(  train_set = train_set, test_set = test_set, y_var = y_var, x_var_num = x_var_num, x_var_cat = x_var_cat, by_var=by_var
              , balancing_method=balancing_method
              , cv_n=cv_n, fip_n=fip_n, hold_n = hold_n, hold_train_sample_size = hold_train_sample_size, hold_test_sample_size = hold_test_sample_size
              , data_check=True, models_list=models_list, correlation = True, model_fip = RandomForestClassifier(n_estimators=30, max_depth=7)
              , simulation_name = simulation_name, description = simulation_description)

# PERFORMANCE (na uzyskane w poprzednim kroku prawdopodobienstwa nadkladamy thresholdy i liczymy scory confusion matrix itp.)
c1.performance(simulation_name=simulation_name, threshold=threshold, priori =  None)

# zapisanie wynikow na dysk
c1.save_results(path = r'C:\Users\memy\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\results\symulacja_1', override = True)
# Out:
# (36139, 6)
# (17801, 6)
# (36139, 6)
# (17801, 6)
# cv 0
# 0
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 1
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 2
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 3
# (27105, 5)
# (9034, 5)
# (17801, 5)
# cv 1
# 0
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 1
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 2
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 3
# (27105, 5)
# (9034, 5)
# (17801, 5)
# hold 0
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# hold 1
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# by_var 0
# (1081, 1)
# (529, 1)
# (17801, 1)
# (3260, 1)
# (1646, 1)
# (17801, 1)
# (14467, 1)
# (7084, 1)
# (17801, 1)
# (9295, 1)
# (4496, 1)
# (17801, 1)
# (8036, 1)
# (4046, 1)
# (17801, 1)
# by_var 1
# (1081, 1)
# (529, 1)
# (17801, 1)
# (3260, 1)
# (1646, 1)
# (17801, 1)
# (14467, 1)
# (7084, 1)
# (17801, 1)
# (9295, 1)
# (4496, 1)
# (17801, 1)
# (8036, 1)
# (4046, 1)
# (17801, 1)
# full 0
# full 1
# feature_importance
# fip 0
# THRESHOLD
# {'0': 0.5, '1': 0.5}
# ('symulacja_1_do_usredn', 'ab', 'test', 'by_var', 0, 'Fair', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'by_var', 1, 'Good', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'by_var', 3, 'Premium', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'cv', 0, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'cv', 1, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'cv', 2, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'cv', 3, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'full', 0, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'full', 0, '_', 1)
# ('symulacja_1_do_usredn', 'ab', 'test', 'hold', 0, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'hold', 1, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'hold', 2, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'test', 'hold', 3, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'by_var', 0, 'Fair', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'by_var', 1, 'Good', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'by_var', 3, 'Premium', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'cv', 0, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'cv', 1, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'cv', 2, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'cv', 3, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'full', 0, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'full', 0, '_', 1)
# ('symulacja_1_do_usredn', 'ab', 'train', 'hold', 0, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'hold', 1, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'hold', 2, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'train', 'hold', 3, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'by_var', 0, 'Fair', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'by_var', 1, 'Good', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'by_var', 3, 'Premium', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'cv', 0, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'cv', 1, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'cv', 2, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'cv', 3, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'hold', 0, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'hold', 1, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'hold', 2, '_', 0)
# ('symulacja_1_do_usredn', 'ab', 'valid', 'hold', 3, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'by_var', 0, 'Fair', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'by_var', 1, 'Good', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'by_var', 3, 'Premium', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'cv', 0, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'cv', 1, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'cv', 2, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'cv', 3, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'full', 0, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'full', 0, '_', 1)
# ('symulacja_1_do_usredn', 'rf', 'test', 'hold', 0, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'hold', 1, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'hold', 2, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'test', 'hold', 3, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'by_var', 0, 'Fair', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'by_var', 1, 'Good', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'by_var', 3, 'Premium', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'cv', 0, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'cv', 1, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'cv', 2, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'cv', 3, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'full', 0, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'full', 0, '_', 1)
# ('symulacja_1_do_usredn', 'rf', 'train', 'hold', 0, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'hold', 1, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'hold', 2, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'train', 'hold', 3, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'by_var', 0, 'Fair', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'by_var', 1, 'Good', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'by_var', 2, 'Ideal', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'by_var', 3, 'Premium', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'by_var', 4, 'Very Good', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'cv', 0, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'cv', 1, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'cv', 2, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'cv', 3, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'hold', 0, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'hold', 1, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'hold', 2, '_', 0)
# ('symulacja_1_do_usredn', 'rf', 'valid', 'hold', 3, '_', 0)

# %% [markdown]
# ### Model 2

# %%
# zmienne
y_var = ['target_multi_label']        # zmianna objasniana
x_var_num = ['y', 'z']                # zmienne objasniajace numeryczne
x_var_cat = ['color','clarity','cut'] # zmienne objasniajace kategoryczne
x_var = x_var_num + x_var_cat         # wszystkie zmienna objasniajace

# podzial na zbioru 'data' na train i test
x_train, x_test, y_train, y_test = skl.model_selection.train_test_split(data[x_var], data[y_var], test_size=0.33)

# reset indexow na zbiorach
x_train = x_train.reset_index(drop=True)
x_test  = x_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test  = y_test.reset_index(drop=True)

# umieszczenie w jednym zbiorze zmiennych objasniajacych i zmiennej objasnianej
train_set = pd.concat([x_train, y_train], axis = 1)
test_set  = pd.concat([x_test, y_test], axis = 1)

# zamiana zmiennej objasnianej na typ 'str'
train_set[y_var] = train_set[y_var].astype(str)
test_set[y_var]  = test_set[y_var].astype(str)

# %%
# Parametry symulacji do UCZENIA MODELI
simulation_name        = 'symulacja_2_do_usredn' # unikalna nazwa symulacji
simulation_description = 'symulacja druga do usredniania' # opis symulacji
models_list            = {'rf':models_base['rf'], 'ab':models_base['ab']} # slownik modeli do nauki wybranych z listy 'model_base'
cv_n                   = 4     # walidacja krzyzowa: ilosc k-foldow na walidacji krzyzowej (None jezeli nie chcemy walidacji krzyzowej)
hold_n                 = 4     # walidacja holdout: ilosc samplow na holdout (None jezeli nie chcemy walidacji holdout)
hold_train_sample_size = 0.1   # walidacja holdout: wielkosc losowanego zbioru train na holdout
hold_test_sample_size  = 0.1   # walidacja holdout: wielkosc losowanego zbioru test na holdout
fip_n                  = 1     # walidacja feature importatnce permutation:  ilosc samplow (None jezeli nie chcemy. Jezeli chcemy, zalecana wartosc to 1)
model_fip              = RandomForestClassifier(n_estimators=20, max_depth=7) # walidacja feature importatnce permutation: okreslenie modelu
by_var                 = 'cut' # walidacja segmentacyjna: zmienna po ktore wykonac segmentacje by_var (None jezeli nie chcemy)
pos_label              = '1'   # ktory label zmiennej objasnianej jest traktowany jako 'positive'
balancing_method       = None  # metoda balansowania (dostepne: ''over', 'under', 'None')
calibration_method     = None # metoda kalibracji prawdopodobienstwa (dostepne : 'isotonic', 'None')
cat_encoding_method    = 'target' # metoda enkodowania zmiennych kategorycznych (dostepne: 'target', 'None')

# parematry dla PERFORMANCE
threshold              = {'0':0.5, '1':0.5} # thresholdy dla kazdej kategorii (jezeli damy 'None' przypisywanie odbywa sie poprzez max(pd))


# inicjalizacja nowego obiektu do symulacji : NIE JEST WYKONYWANA. PRACJEMY DALEJ NA OBIEKCIE W POPRZEDNIEJ SYMULACJI


# UCZENIE MODELI (obliczane tylko prawdopodobienstwa)
c1.simulation(  train_set = train_set, test_set = test_set, y_var = y_var, x_var_num = x_var_num, x_var_cat = x_var_cat, by_var=by_var
              , balancing_method=balancing_method
              , cv_n=cv_n, fip_n=fip_n, hold_n = hold_n, hold_train_sample_size = hold_train_sample_size, hold_test_sample_size = hold_test_sample_size
              , data_check=True, models_list=models_list, correlation = True, model_fip = RandomForestClassifier(n_estimators=30, max_depth=7)
              , simulation_name = simulation_name, description = simulation_description)

# PERFORMANCE (na uzyskane w poprzednim kroku prawdopodobienstwa nadkladamy thresholdy i liczymy scory confusion matrix itp.)
c1.performance(simulation_name=simulation_name, threshold=threshold, priori =  None)

# zapisanie wynikow na dysk
c1.save_results(path = r'C:\Users\memy\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\results\symulacja_1', override = True)
# Out:
# (36139, 6)
# (17801, 6)
# (36139, 6)
# (17801, 6)
# cv 0
# 0
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 1
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 2
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 3
# (27105, 5)
# (9034, 5)
# (17801, 5)
# cv 1
# 0
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 1
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 2
# (27104, 5)
# (9035, 5)
# (17801, 5)
# 3
# (27105, 5)
# (9034, 5)
# (17801, 5)
# hold 0
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# hold 1
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# (3613, 5)
# (3614, 5)
# (17801, 5)
# by_var 0
# (1081, 1)
# (529, 1)
# (17801, 1)
# (3330, 1)
# (1576, 1)
# (17801, 1)
# (14359, 1)
# (7192, 1)
# (17801, 1)
# (9359, 1)
# (4432, 1)
# (17801, 1)
# (8010, 1)
# (4072, 1)
# (17801, 1)
# by_var 1
# (1081, 1)
# (529, 1)
# (17801, 1)
# (3330, 1)
# (1576, 1)
# (17801, 1)
# (14359, 1)
# (7192, 1)
# (17801, 1)
# (9359, 1)
# (4432, 1)
# (17801, 1)
# (8010, 1)
# (4072, 1)
# (17801, 1)
# full 0
# full 1
# feature_importance
# fip 0
# THRESHOLD
# {'0': 0.5, '1': 0.5}
# ('symulacja_2_do_usredn', 'ab', 'test', 'by_var', 0, 'Fair', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'by_var', 1, 'Good', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'by_var', 2, 'Ideal', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'by_var', 3, 'Premium', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'by_var', 4, 'Very Good', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'cv', 0, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'cv', 1, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'cv', 2, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'cv', 3, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'full', 0, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'full', 0, '_', 1)
# ('symulacja_2_do_usredn', 'ab', 'test', 'hold', 0, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'hold', 1, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'hold', 2, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'test', 'hold', 3, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'by_var', 0, 'Fair', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'by_var', 1, 'Good', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'by_var', 2, 'Ideal', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'by_var', 3, 'Premium', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'by_var', 4, 'Very Good', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'cv', 0, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'cv', 1, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'cv', 2, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'cv', 3, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'full', 0, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'full', 0, '_', 1)
# ('symulacja_2_do_usredn', 'ab', 'train', 'hold', 0, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'hold', 1, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'hold', 2, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'train', 'hold', 3, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'by_var', 0, 'Fair', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'by_var', 1, 'Good', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'by_var', 2, 'Ideal', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'by_var', 3, 'Premium', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'by_var', 4, 'Very Good', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'cv', 0, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'cv', 1, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'cv', 2, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'cv', 3, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'hold', 0, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'hold', 1, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'hold', 2, '_', 0)
# ('symulacja_2_do_usredn', 'ab', 'valid', 'hold', 3, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'by_var', 0, 'Fair', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'by_var', 1, 'Good', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'by_var', 2, 'Ideal', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'by_var', 3, 'Premium', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'by_var', 4, 'Very Good', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'cv', 0, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'cv', 1, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'cv', 2, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'cv', 3, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'full', 0, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'full', 0, '_', 1)
# ('symulacja_2_do_usredn', 'rf', 'test', 'hold', 0, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'hold', 1, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'hold', 2, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'test', 'hold', 3, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'by_var', 0, 'Fair', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'by_var', 1, 'Good', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'by_var', 2, 'Ideal', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'by_var', 3, 'Premium', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'by_var', 4, 'Very Good', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'cv', 0, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'cv', 1, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'cv', 2, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'cv', 3, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'full', 0, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'full', 0, '_', 1)
# ('symulacja_2_do_usredn', 'rf', 'train', 'hold', 0, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'hold', 1, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'hold', 2, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'train', 'hold', 3, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'by_var', 0, 'Fair', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'by_var', 1, 'Good', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'by_var', 2, 'Ideal', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'by_var', 3, 'Premium', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'by_var', 4, 'Very Good', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'cv', 0, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'cv', 1, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'cv', 2, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'cv', 3, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'hold', 0, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'hold', 1, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'hold', 2, '_', 0)
# ('symulacja_2_do_usredn', 'rf', 'valid', 'hold', 3, '_', 0)

# %% [markdown]
# ### Usrednienie

# %%
# lista z parami : (1) nazwa_symulacji - (2) model

list_to_stack = {'symulacja_1_do_usredn':'rf', 'symulacja_2_do_usredn':'cat'}

new_simulation_name = 'sim_new'

c1.stacking_between_sim(simulation_new_name = new_simulation_name, simulation_params = list_to_stack, method = 'mean')

# %%
simulation_name = new_simulation_name
h('meta informations about simulation')
c1.simulation_metainfo.loc[c1.simulation_metainfo['simulation_name'] == simulation_name]
h('correlation between features')
c1.fast_correlation_matrices(simulation_name = simulation_name)
h('target distribution, confussion matrix, scores and feature importance')
c1.fast_conf_matrix_scores(simulation_name = simulation_name)
h('density plots')
c1.fast_dens_plot(simulation_name=simulation_name, sample_type = ['full'])
h('density plot for Feature Importatnce Permutation')
c1.fast_dens_plot(simulation_name=simulation_name, sample_type = ['fip'])
h('scores by cross validation')
c1.fast_scores_plot(simulation_name=simulation_name, sample_type = 'cv')
h('scores by holdout')
c1.fast_scores_plot(simulation_name=simulation_name, sample_type = 'hold')
if by_var is not None:
    h('scores by by_var')
    c1.fast_scores_plot(simulation_name=simulation_name, sample_type = 'by_var')
h('pr and roc curve')
c1.plot_roc_pr_curves(simulation_name=simulation_name, set_type='test', sample_type = ['full'], y_category=pos_label)
h('pr and roc curve for Feature Importatnce Permutation')
c1.plot_roc_pr_curves(simulation_name=simulation_name, set_type='test', sample_type = ['fip', 'full'], y_category=pos_label, group = 'model_name', facet = 'sample_nr~variable')
# Out:
# <font size = "3"><b>meta informations about simulation</b></font>
# Empty DataFrame
# Columns: [simulation_name, description, x_n, y_name, y_labels, x_num, x_cat, cat_encoding, balancing, calibration, simulation_start, simulation_end, pos_label, priori, threshold, performance start, performance end]
# Index: []
# <font size = "3"><b>correlation between features</b></font>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_337f578c_acb8_11ea_acfd_985fd3cf311a" style='display:inline'><caption>pearson</caption><thead></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_337f7e92_acb8_11ea_a960_985fd3cf311a" style='display:inline'><caption>kendall</caption><thead></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_337f7e93_acb8_11ea_98a7_985fd3cf311a" style='display:inline'><caption>ratio</caption><thead></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_337fa5a8_acb8_11ea_9ac2_985fd3cf311a" style='display:inline'><caption>v_cramer</caption><thead></thead><tbody>
#         </tbody></table>
# <font size = "3"><b>target distribution, confussion matrix, scores and feature importance</b></font>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_3384f912_acb8_11ea_8cf0_985fd3cf311a" style='display:inline'><caption>target train</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >target_multi_label</th>        <th class="col_heading level0 col2" >proc</th>    </tr></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_33852012_acb8_11ea_b2ca_985fd3cf311a" style='display:inline'><caption>target test</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >target_multi_label</th>        <th class="col_heading level0 col2" >proc</th>    </tr></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_33854706_acb8_11ea_a689_985fd3cf311a" style='display:inline'><caption>thresholds</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33854706_acb8_11ea_a689_985fd3cf311alevel0_row0" class="row_heading level0 row0" >no_threshold</th>
#                         <td id="T_33854706_acb8_11ea_a689_985fd3cf311arow0_col0" class="data row0 col0" >NaN</td>
#             </tr>
#     </tbody></table>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
#
#     <style>
#         div#notebook-container    { width: 95%; }
#         div#menubar-container     { width: 65%; }
#         div#maintoolbar-container { width: 55%; }
#     </style>
# <style  type="text/css" >
# </style><table id="T_33882b1e_acb8_11ea_abc3_985fd3cf311a" style='display:inline'><caption>Feature Importance e-net</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >elastic_net</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33882b1e_acb8_11ea_abc3_985fd3cf311alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_33882b1e_acb8_11ea_abc3_985fd3cf311arow0_col0" class="data row0 col0" >not calculated</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_33887924_acb8_11ea_b9e4_985fd3cf311a" style='display:inline'><caption>Feature Importance RF</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Importance</th>    </tr></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_3388a01e_acb8_11ea_a36a_985fd3cf311a" style='display:inline'><caption>Feature Permutation Importance RF</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Importance</th>    </tr></thead><tbody>
#         </tbody></table>   <style  type="text/css" >
# </style><table id="T_3388c734_acb8_11ea_be3b_985fd3cf311a" style='display:inline'><caption>Feature Importance CATBOOST</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Importance</th>    </tr></thead><tbody>
#         </tbody></table>
# [None,
#  None,
#  None,
#  None,
#  None,
#  'recall = TP / TP + FN;   precision = TP / (TP + FP);    f1 = ( 2*TP ) / (2*TP + FP + FN );   balanced_accuracy = (TP/(TP+FN) + TN/(TN+FP)) / 2 ']
# <font size = "3"><b>density plots</b></font>
# <ggplot: (-9223371868787346951)>
# <ggplot: (-9223371868791007940)>
# <font size = "3"><b>density plot for Feature Importatnce Permutation</b></font>
# ------------------------------------------------------------------
# ValueError                       Traceback (most recent call last)
# <ipython-input-276-cf511cb89e53> in <module>
#       9 c1.fast_dens_plot(simulation_name=simulation_name, sample_type = ['full'])
#      10 h('density plot for Feature Importatnce Permutation')
# ---> 11 c1.fast_dens_plot(simulation_name=simulation_name, sample_type = ['fip'])
#      12 h('scores by cross validation')
#      13 c1.fast_scores_plot(simulation_name=simulation_name, sample_type = 'cv')
#
# ~\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\draft\F_classification.py in fast_dens_plot(self, simulation_name, y_category, score, plot_density_sample_frac, sample_type, fig_w, fig_h)
#    2417                                       , title  = 'train'
#    2418                                       , fig_w  = fig_w
# -> 2419                                       , fig_h  = fig_h) # train
#    2420       ,self.plot_probabilities_density(data_new = None
#    2421                                       , x_var  = y_category
#
# ~\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\draft\F_classification.py in plot_probabilities_density(self, data_new, x_var, filter, fill_var, facet, x_lim, adjust, alpha, size, frac, title, fig_w, fig_h)
#    1837       data = data.sample(frac=frac)
#    1838     else:
# -> 1839       data = data.sample(n = 50000)
#    1840
#    1841     if len(data)== 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    5059             )
#    5060
# -> 5061         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5062         return self.take(locs, axis=axis)
#    5063
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: 'a' must be greater than 0 unless no samples are taken

# %% [markdown]
# ## Stacking

# %% [markdown]
# ## Stack

# %% [markdown]
# # Grid search

# %% [markdown]
# ## Tunning

# %%
# zmienne
y_var = 'target'
x_var = ['price', 'x', 'y']


# podzial danych na train i test
x_train, x_test, y_train, y_test = skl.model_selection.train_test_split(data[x_var], data[y_var], test_size=0.33)
x_train    = x_train.reset_index(drop=True)
y_train    = y_train.reset_index(drop=True)

# konwersja zmiennej y na str
y_train = y_train.astype(str)
y_test  = y_test.astype(str)


# lista thresholdow
thresholds_list = pd.DataFrame({'0':[0.2, 0.4, 0.8]})
thresholds_list['1'] = 1 - thresholds_list['0']

# lita modeli
methods_list = ['RF', 'AB'] # dostepne sa: RF-random forest, AB-adata boost, GB-gradient boost, SVC-wektory nosne, NB-naive bayes, n_neighbors-KNN, XGB-xgboost, CAT-catboost

# UWAGA: lista i zakres wartosci hiterparametrow można zmienic obecnie tylko w samym kodzie funkcji !!!!

priori = None

# ilosc iteracji
n_trials = 3


pos_label = 1

# grid
grid_res = grid_optuna( methods_list = methods_list
            ,thresholds_list = thresholds_list
            ,priori   = None
            ,n_trials = 3
            ,x_train  = x_train
            ,y_train  = y_train
            ,x_test   = x_test
            ,y_test   = y_test)

# wyniki grida
grid_res[0]
grid_res[1]
# Out:
# ['RF', 0]
# [W 2020-06-12 00:18:02,891] Setting status of trial#0 as TrialState.FAIL because of the following error: KeyError('None')
# Traceback (most recent call last):
#   File "C:\Users\memy\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2646, in get_loc
#     return self._engine.get_loc(key)
#   File "pandas\_libs\index.pyx", line 111, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 138, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1619, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1627, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'None'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\memy\Anaconda3\lib\site-packages\optuna\study.py", line 648, in _run_trial
#     result = func(trial)
#   File "C:\Users\memy\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\draft\grid_search.py", line 208, in __call__
#     aps = average_precision_score(y_true=self.y_test, y_score=prob[str(self.pos_label)] , pos_label=str(self.pos_label) )
#   File "C:\Users\memy\Anaconda3\lib\site-packages\pandas\core\frame.py", line 2800, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\memy\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2648, in get_loc
#     return self._engine.get_loc(self._maybe_cast_indexer(key))
#   File "pandas\_libs\index.pyx", line 111, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 138, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1619, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1627, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'None'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'None'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-2e1ad4cfe722> in <module>
#      39             ,y_train  = y_train
#      40             ,x_test   = x_test
# ---> 41             ,y_test   = y_test)
#      42
#      43 # wyniki grida
#
# ~\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\draft\grid_search.py in grid_optuna(methods_list, direction, opt_function, thresholds_list, pos_label, priori, n_trials, x_train, y_train, x_test, y_test)
#     301       ob = Objective(method = method,  opt_function=opt_function, x_train = x_train, y_train = y_train, x_test = x_test, y_test = y_test, threshold=threshold, priori=priori, pos_label = pos_label)
#     302       study = optuna.create_study( direction=direction)
# --> 303       opt = study.optimize(ob, n_trials=n_trials, gc_after_trial=False)
#     304
#     305
#
# ~\Anaconda3\lib\site-packages\optuna\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     317             if n_jobs == 1:
#     318                 self._optimize_sequential(func, n_trials, timeout, catch, callbacks,
# --> 319                                           gc_after_trial, None)
#     320             else:
#     321                 if show_progress_bar:
#
# ~\Anaconda3\lib\site-packages\optuna\study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial, time_start)
#     595                     break
#     596
# --> 597             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     598
#     599             self._progress_bar.update((datetime.datetime.now() - time_start).total_seconds())
#
# ~\Anaconda3\lib\site-packages\optuna\study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     625         # type: (...) -> None
#     626
# --> 627         trial = self._run_trial(func, catch, gc_after_trial)
#     628         if callbacks is not None:
#     629             frozen_trial = self._storage.get_trial(trial._trial_id)
#
# ~\Anaconda3\lib\site-packages\optuna\study.py in _run_trial(self, func, catch, gc_after_trial)
#     646
#     647         try:
# --> 648             result = func(trial)
#     649         except exceptions.TrialPruned as e:
#     650             message = 'Setting status of trial#{} as {}. {}'.format(trial_number,
#
# ~\OneDrive\Pulpit\1_Programs_and_programing\DS_proj\classification_python\draft\grid_search.py in __call__(self, trial)
#     206
#     207       # ta funkcja nie jest napisane pod katem modeli multilabel
# --> 208       aps = average_precision_score(y_true=self.y_test, y_score=prob[str(self.pos_label)] , pos_label=str(self.pos_label) )
#     209
#     210       skm.recall_score(y_true = self.y_test.astype(int), y_pred = classification.astype(int), average = 'binary', pos_label = self.pos_label)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'None'

# %% [markdown]
# ## Wizualizacja

# %%
# getting classification data
data_f = c1.classification.loc[(c1.classification['if_automatic']==if_automatic) & (c1.classification['sample_type']=='full'), :]

# filtering data by models and simulations)
data = pd.DataFrame()
model_name_agg = ''
simulation_name_agg = ''
for params in simulation_params:
    data = pd.concat([data, data_f.loc[(data_f['simulation_name'] == params[0]) & (data_f['model_name'] == params[1]), : ]], axis = 0)
    model_name_agg      = model_name_agg + '_' + params[0]
    simulation_name_agg = simulation_name_agg + '_' + params[1]
# splitting data into train and test (simulations and models are mixed here as we want)
train = data.loc[data['set_type'] == 'train', : ]
test  = data.loc[data['set_type'] == 'test', : ]



# creating indicies columns for aggregated results
group_structure = ['if_automatic', 'model_name', 'sample_nr', 'sample_name', 'sample_type', 'set_type', 'simulation_name']

# model_name_agg = '_'.join(list(simulation_params.values()))
# simulation_name_agg = '_'.join(list(simulation_params.keys()))


# creating empty (with only indicies) data frames to collect aggregated results
train_group = pd.DataFrame([[if_automatic, model_name_agg, 0, 'full', 'train', simulation_name_agg ]], columns = group_structure )
test_group  = pd.DataFrame([[if_automatic, model_name_agg, 0, 'full', 'test',  simulation_name_agg ]], columns = group_structure )

# %%
import optuna
import pandas as pd
import numpy as np

from imblearn.over_sampling    import RandomOverSampler
from imblearn.over_sampling    import SMOTE
from imblearn.under_sampling   import RandomUnderSampler
from plotnine.themes.themeable import axis_line
from sklearn.model_selection   import train_test_split
from sklearn.ensemble          import AdaBoostClassifier
from sklearn.ensemble          import RandomForestClassifier
from sklearn.ensemble          import GradientBoostingClassifier
from sklearn.linear_model      import LogisticRegression
from sklearn.naive_bayes       import MultinomialNB
# from xgboost                   import XGBClassifier
from sklearn.svm               import SVC
import sklearn.metrics as skm
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve, auc










methods_list = methods_list
thresholds_list = thresholds_list
priori   = None
n_trials = 3
x_train  = x_train
y_train  = y_train
x_test   = x_test
y_test   = y_test





















class Objective(object):
    def __init__( self
                , method       = 'RF'
                , opt_function = 'aps'
                , calibration_method = None
                , pos_label = None
                , params    = None
                , threshold = None
                , priori    = None
                , x_train   = None
                , y_train   = None
                , x_test    = None
                , y_test    = None):
        # Hold this implementation specific arguments as the fields of the class.
        self.method    = method
        self.opt_function       = opt_function
        self.calibration_method = calibration_method
        self.params    = params
        self.threshold = threshold
        self.priori    = priori
        self.x_train   = x_train
        self.y_train   = y_train
        self.x_test    = x_test
        self.y_test    = y_test
        self.scores    = pd.DataFrame()
        self.y_labels  = None 
        self.pos_label = pos_label
        # self.x_var_num_range = x_var_num_range
    
    def __call__(self, trial):
      
      
      if self.method == 'SVC': # support vectors machine
        
        SVM_params = {
        'svc_c':  trial.suggest_loguniform('svc_c', 1e-10, 1e10)}
        if self.params is not None:
          SVM_params.update(params)
        model = sklearn.svm.SVC(**SVM_params)
        
      elif self.method == 'RF': # random forest
      
        # https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier.feature_importances_
        RF_params = {
           'n_estimators': int(trial.suggest_uniform('n_estimators', 20, 300))
          ,'max_depth'   : int(trial.suggest_uniform('max_depth', 2, 50))
          ,'criterion'   : trial.suggest_categorical('criterion', ['gini', 'entropy'])
          ,'bootstrap'   : trial.suggest_categorical('bootstrap', [True, False])
          ,'class_weight': trial.suggest_categorical('class_weight', ['balanced', 'balanced_subsample', None])
          }
        if self.params is not None:
          RF_params.update(params)
        model = RandomForestClassifier(**RF_params, n_jobs = 15)
        
      elif self.method == 'AB': # ada boost
        
        AB_params = {
         'n_estimators' : int(trial.suggest_uniform('n_estimators', 20, 300))
        ,'learning_rate': trial.suggest_uniform('learning_rate', 0.05, 0.3)
        ,'algorithm'    : trial.suggest_categorical('algorithm', ['SAMME.R', 'SAMME'])
        }
        if self.params is not None:
          AB_params.update(params)
        model = AdaBoostClassifier(**AB_params)
        
      elif self.method == 'GB': # gradient boost
        
        GB_params = {
         'n_estimators' : int(trial.suggest_loguniform('n_estimators', 20, 300))
        ,'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5)
        ,'max_depth'    : int(trial.suggest_loguniform('max_depth', 2, 50))
        ,'loss'         : trial.suggest_categorical('loss', ['deviance', 'exponential'])
        }
        if self.params is not None:
          GB_params.update(params)
        model = GradientBoostingClassifier(**GB_params)
        
      elif self.method == 'NB': # naive bayes
        
        NB_params = {
          'var_smoothing' : trial.suggest_loguniform('var_smoothing', 1e-10, 1e-05)
          }
        if self.params is not None:
          NB_params.update(params)
        model = skl.naive_bayes.GaussianNB(**NB_params)
        
      elif self.method == 'KNN': # k-nearest neighbours
        
        KNN_params = {
          'n_neighbors' : int(trial.suggest_loguniform('n_neighbors', 3, 7))
          }
        if self.params is not None:
          KNN_params.update(params)
        model = skl.neighbors.KNeighborsClassifier(**KNN_params)
        
      elif self.method == 'LR': # logistic retression
        LR_params = {
           'penalty'       : trial.suggest_categorical('penalty', ['l1', 'l2'])
          ,'fit_intercept' : trial.suggest_categorical('fit_intercept', [True, False])
          }
        if self.params is not None:
          LR_params.update(params)
        model = skl.linear_model.LogisticRegression(**LR_params)
        
      elif self.method == 'XGB': # XGBoost
      
        # https://xgboost.readthedocs.io/en/latest/parameter.html
        XGB_params = {
             'n_estimators': int(trial.suggest_loguniform( 'n_estimators', 5, 300))
            ,'booster'   :       trial.suggest_categorical('booster', ['dart','gbtree'])
            ,'eta'       :       trial.suggest_loguniform( 'eta', 0.01, 0.5)
            ,'max_depth' :   int(trial.suggest_loguniform( 'max_depth', 3, 30))
            # ,'reg_lambda':       trial.suggest_loguniform( 'reg_lambda', 0, 1)
            # ,'reg_alpha' :       trial.suggest_loguniform( 'reg_alpha', 0, 1)
          }
        if self.params is not None:
          XGB_params.update(params)
        model = XGBClassifier(**XGB_params, nthread = 15)
        
      elif self.method == 'CAT': # catboost
      
        # https://catboost.ai/docs/concepts/python-reference_parameters-list.html#python-reference_parameters-list
        CAT_params = {
           'iterations'    : int(trial.suggest_loguniform('iterations', 20, 300))
          ,'learning_rate' :     trial.suggest_loguniform('learning_rate', 0.01, 0.5)
          ,'depth'         : int(trial.suggest_loguniform('depth', 2, 16))
          }
        if self.params is not None:
          CAT_params.update(params)
        model = CatBoostClassifier(**CAT_params, early_stopping_rounds=75,  logging_level='Silent')
      
      # calibration (optional)
      if self.calibration_method is not None:
        model = CalibratedClassifierCV(model, cv=3, method=self.calibration_method)
      
      # model fit
      model.fit(self.x_train, self.y_train)
      
      # y labels
      y_labels        = list(self.y_train.drop_duplicates())
      y_labels.sort()
      self.y_labels   = y_labels
      
      # model prediction and classification
      prob = pd.DataFrame(model.predict_proba(self.x_test), columns = [str(x) for x in model.classes_])
      prob = prob.reset_index(drop=True)
      if self.priori is not None:
        
        for p in range(prob.shape[1]):
          var = prob.columns[p]
          priori_p = self.priori[var]
          prob.iloc[:,p] = prob.iloc[:,p] * priori_p
          prob_sum = prob.apply(lambda x: 1/sum(x), axis = 1)
          
          for p in self.y_labels :
            prob.loc[:,p] = prob.loc[:,p]*prob_sum 
            
      if prob.shape[1] == 2 and self.threshold is not None:
        var_1 = list(self.threshold.keys())[0]
        var_2 = list(self.threshold.keys())[1]
        threshold_var_1 = list(self.threshold.values())[0]
        threshold_var_2 = list(self.threshold.values())[1]
        classification = pd.DataFrame([var_1 if x >= threshold_var_1 else var_2 for x in prob[str(var_1)]])
        
      else:
        classification =  pd.DataFrame(prob.idxmax(axis = 1)) # zapis jako DataFrame by dalej zrobić 'concat'
      
      
      # selection and determining score function to optimize
      
      balanced_accuracy = skm.balanced_accuracy_score(y_true = self.y_test, y_pred = classification)
      accuracy          = skm.accuracy_score(y_true  = self.y_test, y_pred = classification)
      
      # ta funkcja nie jest napisane pod katem modeli multilabel
      aps = average_precision_score(y_true=self.y_test, y_score=prob[str(self.pos_label)] , pos_label=str(self.pos_label) )
      
      skm.recall_score(y_true = self.y_test.astype(int), y_pred = classification.astype(int), average = 'binary', pos_label = self.pos_label)
      
      # recall
      try:
        if len(self.y_labels) < 3:
          recall  = skm.recall_score(y_true = self.y_test.astype(int), y_pred = classification.astype(int), average = 'binary', pos_label = self.pos_label)
        else:
          recall = skm.recall_score(y_true = self.y_test.astype(str), y_pred = classification.astype(str), average = 'weighted')
      except:
          recall = np.nan
      
      # precision
      try:
        if len(self.y_labels) < 3:
          precision  = skm.precision_score(y_true = self.y_test.astype(int), y_pred = classification.astype(int), average = 'binary', pos_label = self.pos_label)
        else:
          precision = skm.precision_score(y_true = self.y_test.astype(str), y_pred = classification.astype(str), average = 'weighted')
      except:
          precision = np.nan
      
      # f1
      try:
        if len(self.y_labels) < 3:
          f1 = skm.f1_score(y_true = self.y_test, y_pred = classification, average = 'binary', pos_label = str(self.pos_label))
        else:
          f1 = skm.f1_score(y_true = self.y_test, y_pred = classification, average = 'weighted')
      except:
        f1 = np.nan
      
      scores = pd.DataFrame([[balanced_accuracy, accuracy, recall, precision, f1, aps]], columns = ['balanced_accuracy', 'accuracy', 'recall', 'precision', 'f1', 'aps'])
      
      self.scores = pd.concat([self.scores, scores])
      
      if self.opt_function == 'balanced_accuracy':
        return(balanced_accuracy)
      elif self.opt_function == 'aps':
        return(aps)
      elif self.opt_function == 'accuracy':
        return(accuracy)
      elif self.opt_function == 'recall':
        return(recall)
      elif self.opt_function == 'precision':
        return(precision)


# y_train = y_train.astype(str)
# y_test = y_test.astype(str)
#       
# ob = Objective(method = 'RF',  x_train = x_train, y_train = y_train, x_test = x_test, y_test = y_test, threshold={'0':0.5, '1':0.5}, priori=None, pos_label=1, opt_function='aps')
# #
# study = optuna.create_study()
# #
# opt = study.optimize(ob, n_trials=3)


##################



def grid_optuna(  methods_list = None
                , direction    = "maximize"
                , opt_function = 'aps'
                , thresholds_list = None
                , pos_label = None
                ,  priori   = None
                , n_trials  = 10
                , x_train   = None
                , y_train   = None
                , x_test    = None
                , y_test    = None):
  
  """
  
  """
  
  trial_scores          = pd.DataFrame()
  trial_hyperparameters = pd.DataFrame()
  threshold_columns     = list(thresholds_list.columns)
  
  # loop over models
  for i in range(len(methods_list)): 
    
    # loop over thresholds
    method = methods_list[i]
    for j in range(len(thresholds_list)):
      
      print([method,j])
      
      threshold = {threshold_columns[0]:thresholds_list.iloc[j,0], threshold_columns[1]:thresholds_list.iloc[j,1]}
      
      # grid
      ob = Objective(method = method,  opt_function=opt_function, x_train = x_train, y_train = y_train, x_test = x_test, y_test = y_test, threshold=threshold, priori=priori, pos_label = pos_label)
      study = optuna.create_study( direction=direction)
      opt = study.optimize(ob, n_trials=n_trials, gc_after_trial=True) 
      
      
      # getting scores from trials of grid
      trial_scores_ij = ob.scores
      
      # preparing scores to collect
      trial_scores_ij['method'] = method
      trial_scores_ij['threshold'] = thresholds_list.iloc[j,0]
      trial_scores_ij = trial_scores_ij.reset_index(drop = True)
      trial_scores_ij = trial_scores_ij.reset_index(drop = False)
      
      trial_scores = pd.concat([trial_scores, trial_scores_ij], ignore_index = True)
      trial_scores = trial_scores.rename({'index':'number'})
      
      
      # getting hyperparameters from trials of grid
      trial_hiperparameters_ij = study.trials_dataframe()
      
      # preparing hyperparameters to collect
      trial_hiperparameters_ij = trial_hiperparameters_ij.drop(['datetime_start','datetime_complete','system_attrs__number','state'], axis = 1)
      trial_hiperparameters_ij = trial_hiperparameters_ij.melt(id_vars = ['number'])
      
      trial_hiperparameters_ij['method'] = method
      trial_hiperparameters_ij['threshold'] = thresholds_list.iloc[j,0]
      
      trial_hyperparameters = pd.concat([trial_hyperparameters, trial_hiperparameters_ij], ignore_index=True)
      
  return([trial_scores, trial_hyperparameters])  

# data = r.diamonds
# data['target'] = pd.Series(np.random.randint(0,2, len(data) ))
# data['target'] = data['target'].astype(str)
# 
# y_var = 'target'
# x_var = ['price', 'x', 'y']
# 
# # podstawowy zbior danych
# x_train, x_test, y_train, y_test = skl.model_selection.train_test_split(data[x_var], data[y_var], test_size=0.33)
# x_train    = x_train.reset_index(drop=True)
# y_train    = y_train.reset_index(drop=True)
# 
# 
# 
# thresholds_list = pd.DataFrame({'0':[0.2, 0.4, 0.8]})
# thresholds_list['1'] = 1 - thresholds_list['0']
# 
# methods_list = ['RF', 'AB']
# 
# priori = None
# n_trials = 5
# 
# 
# grid_res = grid_optuna( methods_list = methods_list
#             ,thresholds_list = thresholds_list
#             ,priori   = None
#             ,n_trials = 3
#             ,x_train  = x_train
#             ,y_train  = y_train
#             ,x_test   = x_test
#             ,y_test   = y_test)
# 
# grid_res[0]
# grid_res[1]


def grid_optuna_scores_plot(data, fig_w = 10, fig_h = 10):
  """
  Line plot of scores from grid search
  """
  plotnine.options.figure_size = (fig_w, fig_h)
  data = pd.melt(frame=data, id_vars=['index', 'method', 'threshold'])
  data['threshold'] = data['threshold'].astype(str) 
  print(ggplot(data = data) + geom_line(aes(x = 'index', y = 'value', color = 'threshold')) + facet_grid('variable~method', scales  = 'free_y') )

# TEST CODE:
# grid_optuna_scores_plot(grid_res[0])


def grid_optuna_hyperparameters_plot(data = None, method = 'RF', params_to_print = None, fig_w = 10, fig_h = 5):
  """
  Line plot of hyperparameters from grid search
  """
  plotnine.options.figure_size = (fig_w, fig_h)
  params_to_print = ['params_' + x for x in params_to_print]
  data = data.loc[(data['variable'].isin(params_to_print)) & (data['method'].isin([method])), :]
  data['value'] = data['value'].astype(float)
  data['threshold'] = data['threshold'].astype(str)
  
  # print(ggplot(data = trials) + geom_line(aes(x = 'number', y = 'value'))  +  facet_grid('.~threshold') + ggtitle('score'))
  print(ggplot(data=data) + geom_line(aes(x = 'number', y='value', color = 'threshold')) + facet_grid('variable~method', scales = 'free_y') + ggtitle(method))

# TEST CODE:
# grid_optuna_hyperparameters_plot(data = grid_res[1], params_to_print = ['n_estimators', 'max_depth'], method = 'RF')
# Out:
# '\nStep plot of "roc-curve" and "precision-recall-curve".\n'
# rf
# <ggplot: (110596959289)>
# <ggplot: (-9223371926196514423)>
#             average_precision
# rf - 0 - 0              0.619
# rf - 0 - 4              0.523
# rf - 0 - 1              0.424
# rf - 0 - 3              0.399
# rf - 0 - 2              0.356
#             roc_auc
# rf - 0 - 4    0.898
# rf - 0 - 2    0.798
# rf - 0 - 0    0.732
# rf - 0 - 1    0.688
# rf - 0 - 3    0.680

# %%
class Objective(object):
    def __init__( self
                , method       = 'RF'
                , opt_function = 'aps'
                , calibration_method = None
                , pos_label = None
                , params    = None
                , threshold = None
                , priori    = None
                , x_train   = None
                , y_train   = None
                , x_test    = None
                , y_test    = None):
        # Hold this implementation specific arguments as the fields of the class.
        self.method    = method
        self.opt_function       = opt_function
        self.calibration_method = calibration_method
        self.params    = params
        self.threshold = threshold
        self.priori    = priori
        self.x_train   = x_train
        self.y_train   = y_train
        self.x_test    = x_test
        self.y_test    = y_test
        self.scores    = pd.DataFrame()
        self.y_labels  = None 
        self.pos_label = pos_label
        # self.x_var_num_range = x_var_num_range
    
    def __call__(self, trial):
      
      
      # optional variables sampling ( to implement in the future)
      
      # if x_var_num_range is not None:
      #   number_of_var = list(range(self.x_var_num_range[0], self.x_var_num_range[1]+1))
      #   x_var = np.random.choice(list(x_var.columns), number_of_var)
      # else:
      #   x_var = x_train.columns
      
      
      if self.method == 'SVC': # support vectors machine
        
        SVM_params = {
        'svc_c':  trial.suggest_loguniform('svc_c', 1e-10, 1e10)}
        if self.params is not None:
          SVM_params.update(params)
        model = sklearn.svm.SVC(**SVM_params)
        
      elif self.method == 'RF': # random forest
      
        # https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier.feature_importances_
        RF_params = {
           'n_estimators': int(trial.suggest_uniform('n_estimators', 20, 300))
          ,'max_depth'   : int(trial.suggest_uniform('max_depth', 2, 50))
          ,'criterion'   : trial.suggest_categorical('criterion', ['gini', 'entropy'])
          ,'bootstrap'   : trial.suggest_categorical('bootstrap', [True, False])
          ,'class_weight': trial.suggest_categorical('class_weight', ['balanced', 'balanced_subsample', None])
          }
        if self.params is not None:
          RF_params.update(params)
        model = RandomForestClassifier(**RF_params, n_jobs = 15)
        
      elif self.method == 'AB': # ada boost
        
        AB_params = {
         'n_estimators' : int(trial.suggest_uniform('n_estimators', 20, 300))
        ,'learning_rate': trial.suggest_uniform('learning_rate', 0.05, 0.3)
        ,'algorithm'    : trial.suggest_categorical('algorithm', ['SAMME.R', 'SAMME'])
        }
        if self.params is not None:
          AB_params.update(params)
        model = AdaBoostClassifier(**AB_params)
        
      elif self.method == 'GB': # gradient boost
        
        GB_params = {
         'n_estimators' : int(trial.suggest_loguniform('n_estimators', 20, 300))
        ,'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5)
        ,'max_depth'    : int(trial.suggest_loguniform('max_depth', 2, 50))
        ,'loss'         : trial.suggest_categorical('loss', ['deviance', 'exponential'])
        }
        if self.params is not None:
          GB_params.update(params)
        model = GradientBoostingClassifier(**GB_params)
        
      elif self.method == 'NB': # naive bayes
        
        NB_params = {
          'var_smoothing' : trial.suggest_loguniform('var_smoothing', 1e-10, 1e-05)
          }
        if self.params is not None:
          NB_params.update(params)
        model = skl.naive_bayes.GaussianNB(**NB_params)
        
      elif self.method == 'KNN': # k-nearest neighbours
        
        KNN_params = {
          'n_neighbors' : int(trial.suggest_loguniform('n_neighbors', 3, 7))
          }
        if self.params is not None:
          KNN_params.update(params)
        model = skl.neighbors.KNeighborsClassifier(**KNN_params)
        
      elif self.method == 'LR': # logistic retression
        LR_params = {
           'penalty'       : trial.suggest_categorical('penalty', ['l1', 'l2'])
          ,'fit_intercept' : trial.suggest_categorical('fit_intercept', [True, False])
          }
        if self.params is not None:
          LR_params.update(params)
        model = skl.linear_model.LogisticRegression(**LR_params)
        
      elif self.method == 'XGB': # XGBoost
      
        # https://xgboost.readthedocs.io/en/latest/parameter.html
        XGB_params = {
             'n_estimators': int(trial.suggest_loguniform( 'n_estimators', 5, 300))
            ,'booster'   :       trial.suggest_categorical('booster', ['dart','gbtree'])
            ,'eta'       :       trial.suggest_loguniform( 'eta', 0.01, 0.5)
            ,'max_depth' :   int(trial.suggest_loguniform( 'max_depth', 3, 30))
            # ,'reg_lambda':       trial.suggest_loguniform( 'reg_lambda', 0, 1)
            # ,'reg_alpha' :       trial.suggest_loguniform( 'reg_alpha', 0, 1)
          }
        if self.params is not None:
          XGB_params.update(params)
        model = XGBClassifier(**XGB_params, nthread = 15)
        
      elif self.method == 'CAT': # catboost
      
        # https://catboost.ai/docs/concepts/python-reference_parameters-list.html#python-reference_parameters-list
        CAT_params = {
           'iterations'    : int(trial.suggest_loguniform('iterations', 20, 300))
          ,'learning_rate' :     trial.suggest_loguniform('learning_rate', 0.01, 0.5)
          ,'depth'         : int(trial.suggest_loguniform('depth', 2, 16))
          }
        if self.params is not None:
          CAT_params.update(params)
        model = CatBoostClassifier(**CAT_params, early_stopping_rounds=75,  logging_level='Silent')
      
      # calibration (optional)
      if self.calibration_method is not None:
        model = CalibratedClassifierCV(model, cv=3, method=self.calibration_method)
      
      # model fit
      model.fit(self.x_train, self.y_train)
      
      # y labels
      y_labels        = list(self.y_train.drop_duplicates())
      y_labels.sort()
      self.y_labels   = y_labels
      
      # model prediction and classification
      prob = pd.DataFrame(model.predict_proba(self.x_test), columns = [str(x) for x in model.classes_])
      prob = prob.reset_index(drop=True)
      if self.priori is not None:
        
        for p in range(prob.shape[1]):
          var = prob.columns[p]
          priori_p = self.priori[var]
          prob.iloc[:,p] = prob.iloc[:,p] * priori_p
          prob_sum = prob.apply(lambda x: 1/sum(x), axis = 1)
          
          for p in self.y_labels :
            prob.loc[:,p] = prob.loc[:,p]*prob_sum 
            
      if prob.shape[1] == 2 and self.threshold is not None:
        var_1 = list(self.threshold.keys())[0]
        var_2 = list(self.threshold.keys())[1]
        threshold_var_1 = list(self.threshold.values())[0]
        threshold_var_2 = list(self.threshold.values())[1]
        classification = pd.DataFrame([var_1 if x >= threshold_var_1 else var_2 for x in prob[str(var_1)]])
        
      else:
        classification =  pd.DataFrame(prob.idxmax(axis = 1)) # zapis jako DataFrame by dalej zrobić 'concat'
      
      
      # selection and determining score function to optimize
      
      balanced_accuracy = skm.balanced_accuracy_score(y_true = self.y_test, y_pred = classification)
      accuracy          = skm.accuracy_score(y_true  = self.y_test, y_pred = classification)
      
      # ta funkcja nie jest napisane pod katem modeli multilabel
      aps = average_precision_score(y_true=self.y_test, y_score=prob[str(self.pos_label)] , pos_label=str(self.pos_label) )
      
      skm.recall_score(y_true = self.y_test.astype(int), y_pred = classification.astype(int), average = 'binary', pos_label = self.pos_label)
      
      # recall
      try:
        if len(self.y_labels) < 3:
          recall  = skm.recall_score(y_true = self.y_test.astype(int), y_pred = classification.astype(int), average = 'binary', pos_label = self.pos_label)
        else:
          recall = skm.recall_score(y_true = self.y_test.astype(str), y_pred = classification.astype(str), average = 'weighted')
      except:
          recall = np.nan
      
      # precision
      try:
        if len(self.y_labels) < 3:
          precision  = skm.precision_score(y_true = self.y_test.astype(int), y_pred = classification.astype(int), average = 'binary', pos_label = self.pos_label)
        else:
          precision = skm.precision_score(y_true = self.y_test.astype(str), y_pred = classification.astype(str), average = 'weighted')
      except:
          precision = np.nan
      
      # f1
      try:
        if len(self.y_labels) < 3:
          f1 = skm.f1_score(y_true = self.y_test, y_pred = classification, average = 'binary', pos_label = str(self.pos_label))
        else:
          f1 = skm.f1_score(y_true = self.y_test, y_pred = classification, average = 'weighted')
      except:
        f1 = np.nan
      
      scores = pd.DataFrame([[balanced_accuracy, accuracy, recall, precision, f1, aps]], columns = ['balanced_accuracy', 'accuracy', 'recall', 'precision', 'f1', 'aps'])
      
      self.scores = pd.concat([self.scores, scores])
      
      if self.opt_function == 'balanced_accuracy':
        return(balanced_accuracy)
      elif self.opt_function == 'aps':
        return(aps)
      elif self.opt_function == 'accuracy':
        return(accuracy)
      elif self.opt_function == 'recall':
        return(recall)
      elif self.opt_function == 'precision':
        return(precision)
